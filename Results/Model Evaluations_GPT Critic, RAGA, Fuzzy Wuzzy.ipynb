# %% [markdown]
# ## Fuzzy Wuzzy Method

# %%
import pandas as pd
from fuzzywuzzy import fuzz

llm_output_df = pd.read_csv("Temperature1_WithoutExamples_cleaned.csv")

annotations_df = pd.read_csv("Annotations.csv")
# Out:
# /opt/miniconda3/lib/python3.12/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#Simple Ratio: When both strings are expected to be in similar order and fully comparable.
#**Partial Ratio: When one string is a part of the other or has extra noise (e.g., extra words).
#**Token Sort Ratio: When the strings have the same words but may be in a different order.
#Token Set Ratio: When the strings have repeated or redundant words and you want to focus on unique words.

# try a search method and isolate highest similarity

# %%
columns_to_compare = ['subj', 'rel', 'obj']

#karrouri, 12 anti, fava 



low_similarity_threshold = 30
overall_similarity_scores = []
count=0

for idx in range(min(len(annotations_df), len(llm_output_df))):
    similarity_scores = []
    
    for col in columns_to_compare:
        handwritten = annotations_df.iloc[idx][col]
        llm = llm_output_df.iloc[idx][col]
        
        #partial ratio because the words should be similar but there can be extra words around 
        similarity_score = fuzz.partial_ratio(handwritten, llm)
        similarity_scores.append(similarity_score)
    

    average_similarity = sum(similarity_scores) / len(similarity_scores)
    overall_similarity_scores.append(average_similarity)
    

#     if average_similarity < low_similarity_threshold:
        

#         print(f"Row {idx} in annotations has low similarity (Avg score: {average_similarity}):")
#         print(annotations_df.iloc[idx])
#         print('---------------------------')
#         print(llm_output_df.iloc[idx])
#         count+=1
    if average_similarity > low_similarity_threshold:
        print(annotations_df.iloc[idx])
        print('---------------------------')
        print(llm_output_df.iloc[idx])
        count+=1
        print('===========================')
        
overall_similarity_score = sum(overall_similarity_scores) / len(overall_similarity_scores)
print(f"\nOverall Similarity Score: {overall_similarity_score}")
print(f"These are the mismatches: {count}")
# Out:
# subj           Depression
# rel           Side effect
# obj     Suicidal behavior
# Name: 0, dtype: object
# ---------------------------
# Unnamed: 0                                                    0
# subj                                  Major Depressive Disorder
# rel                                                  Definition
# obj           a prevalent psychiatric disorder that often le...
# Name: 0, dtype: object
# ===========================
# subj     Depression
# rel     Side effect
# obj       Mortality
# Name: 1, dtype: object
# ---------------------------
# Unnamed: 0                                                    1
# subj          Selective Serotonin Reuptake Inhibitor antidep...
# rel                                        first-line treatment
# obj                                   Major Depressive Disorder
# Name: 1, dtype: object
# ===========================
# subj                      Depression
# rel                      Side effect
# obj     Slower response to treatment
# Name: 2, dtype: object
# ---------------------------
# Unnamed: 0                                   2
# subj          Depression-focused psychotherapy
# rel                      second-line treatment
# obj                  Major Depressive Disorder
# Name: 2, dtype: object
# ===========================
# subj              Pharmacotherapy
# rel                        Treats
# obj     Acute phase of depression
# Name: 3, dtype: object
# ---------------------------
# Unnamed: 0                            3
# subj          Electroconvulsive therapy
# rel                              Treats
# obj                          Depression
# Name: 3, dtype: object
# ===========================
# subj    Pharmacotherapy
# rel             Entails
# obj                TCAs
# Name: 6, dtype: object
# ---------------------------
# Unnamed: 0                                                    6
# subj          Combination of medication, psychotherapy, and ...
# rel                                                      Treats
# obj                                resistant form of depression
# Name: 6, dtype: object
# ===========================
# subj                       Pharmacotherapy
# rel                                Entails
# obj     Norepinephrine reuptake inhibitors
# Name: 7, dtype: object
# ---------------------------
# Unnamed: 0                                                    7
# subj                                                   Ketamine
# rel                                                Side effects
# obj           dizziness, neurotoxicity, cognitive dysfunctio...
# Name: 7, dtype: object
# ===========================
# subj    Pharmacotherapy
# rel             Entails
# obj            Ketamine
# Name: 8, dtype: object
# ---------------------------
# Unnamed: 0                                             8
# subj                             Vagus Nerve Stimulation
# rel                                               Treats
# obj           resistant unilateral or bipolar depression
# Name: 8, dtype: object
# ===========================
# subj              Monoamine oxidase inhibitors
# rel                               Side effects
# obj     Hepatotoxicity and hypertensive crises
# Name: 9, dtype: object
# ---------------------------
# Unnamed: 0                                                    9
# subj                                          Physical exercise
# rel                                             Associated with
# obj           improvement in depression symptom and preventi...
# Name: 9, dtype: object
# ===========================
# subj    Monoamine oxidase inhibitors
# rel                 Same efficacy as
# obj        Tricyclic antidepressants
# Name: 10, dtype: object
# ---------------------------
# Unnamed: 0                                                    0
# subj                                             All Depression
# rel                                                  Definition
# obj           a prevalent psychiatric disorder that often le...
# Name: 10, dtype: object
# ===========================
# subj                         Monoamine oxidase inhibitors
# rel            Demonstrated specific efficacy in treating
# obj     Atypical features, such as reactive moods, rev...
# Name: 11, dtype: object
# ---------------------------
# Unnamed: 0                                                  1
# subj          Selective Serotonin Reuptake Inhibitors (SSRIs)
# rel                                      first-line treatment
# obj                                            All Depression
# Name: 11, dtype: object
# ===========================
# subj                       Monoamine oxidase inhibitors
# rel                                        Eligible for
# obj     Patients who do not respond to other treatments
# Name: 12, dtype: object
# ---------------------------
# Unnamed: 0                                                    2
# subj                                         Anxious Depression
# rel                                            more common than
# obj           nonanxious depression in African American grou...
# Name: 12, dtype: object
# ===========================
# subj              SSRIs
# rel        Is a part of
# obj     Pharmacotherapy
# Name: 13, dtype: object
# ---------------------------
# Unnamed: 0                                                    3
# subj                            Electroconvulsive therapy (ECT)
# rel                                            Highly effective
# obj           somatic therapy for depression in some specifi...
# Name: 13, dtype: object
# ===========================
# subj                        SSRIs
# rel                         Treat
# obj     Acute phase of depression
# Name: 14, dtype: object
# ---------------------------
# Unnamed: 0                                                    4
# subj                                                   Ketamine
# rel                                                  Properties
# obj           very quick effects on resistant unipolar depre...
# Name: 14, dtype: object
# ===========================
# subj      Norepinephrine reuptake inhibitors
# rel                             Eligible for
# obj     Patients who do not respond to SSRIs
# Name: 17, dtype: object
# ---------------------------
# Unnamed: 0                                   7
# subj          Depression-focused psychotherapy
# rel                      second-line treatment
# obj                             All Depression
# Name: 17, dtype: object
# ===========================
# subj                              Trazodone
# rel                                     Use
# obj     In low doses as a sedative hypnotic
# Name: 18, dtype: object
# ---------------------------
# Unnamed: 0                    8
# subj          Physical exercise
# rel                      Treats
# obj              All Depression
# Name: 18, dtype: object
# ===========================
# subj          Nefazodone
# rel     Is comparable to
# obj                 SSRI
# Name: 19, dtype: object
# ---------------------------
# Unnamed: 0                                                    9
# subj                                            Psychoeducation
# rel                                                        Goal
# obj           educate depressed patients and family members ...
# Name: 19, dtype: object
# ===========================
# subj                                           Nefazodone
# rel                                          Side effects
# obj     Rare cases of clinical idiosyncratic hepatotox...
# Name: 20, dtype: object
# ---------------------------
# Unnamed: 0                                                    0
# subj                                  Major Depressive Disorder
# rel                                                  Definition
# obj           a prevalent psychiatric disorder leading to po...
# Name: 20, dtype: object
# ===========================
# subj                                         Bupropion
# rel                                         Properties
# obj     Norepinephrine and dopamine reuptake inhibitor
# Name: 21, dtype: object
# ---------------------------
# Unnamed: 0                                                    1
# subj          Selective Serotonin Reuptake Inhibitor antidep...
# rel                                        first-line treatment
# obj            Major Depressive Disorder during the acute phase
# Name: 21, dtype: object
# ===========================
# subj                                            Bupropion
# rel                                            Properties
# obj     Has a more activating profile than SSRIs that ...
# Name: 22, dtype: object
# ---------------------------
# Unnamed: 0                                                    2
# subj                                  Electroconvulsive therapy
# rel                                                  Definition
# obj           the most effective somatic therapy for depress...
# Name: 22, dtype: object
# ===========================
# subj                                            Bupropion
# rel                                            Properties
# obj     A better tolerability than SSRIs, with minimal...
# Name: 23, dtype: object
# ---------------------------
# Unnamed: 0                                                    3
# subj                              Resistant forms of depression
# rel                                                      Treats
# obj           Combination of medication, psychotherapy, and ...
# Name: 23, dtype: object
# ===========================
# subj                                            Mianserin
# rel                                            Properties
# obj     Increases norepinephrine and dopamine release ...
# Name: 26, dtype: object
# ---------------------------
# Unnamed: 0                                                    6
# subj          Cognitive Behavioral Therapy and Interpersonal...
# rel                                        first-line treatment
# obj                  Mild to moderate Major Depressive Disorder
# Name: 26, dtype: object
# ===========================
# subj                                          Mirtazapine
# rel                                             Increases
# obj     Availability of serotonin or norepinephrine (o...
# Name: 27, dtype: object
# ---------------------------
# Unnamed: 0                                                    0
# subj          Mirtazapine, Escitalopram, Venlafaxine, Sertra...
# rel                                              More effective
# obj           Duloxetine, Fluoxetine, Fluvoxamine, Paroxetin...
# Name: 27, dtype: object
# ===========================
# subj        Mirtazapine
# rel     As effective as
# obj               SSRIs
# Name: 28, dtype: object
# ---------------------------
# Unnamed: 0                            1
# subj                         Reboxetine
# rel                      Less effective
# obj           All other antidepressants
# Name: 28, dtype: object
# ===========================
# subj                        Ketamine
# rel                   Has effects on
# obj     Unipolar, bipolar depression
# Name: 29, dtype: object
# ---------------------------
# Unnamed: 0                                                    2
# subj                                Escitalopram and Sertraline
# rel                                        Better acceptability
# obj           Duloxetine, Fluvoxamine, Paroxetine, Reboxetin...
# Name: 29, dtype: object
# ===========================
# subj                                             Ketamine
# rel                                          Side effects
# obj     dizziness, neurotoxicity, cognitive dysfunctio...
# Name: 30, dtype: object
# ---------------------------
# Unnamed: 0                                                    3
# subj                                Escitalopram and Sertraline
# rel                                                    Overview
# obj           Good balance between benefits, acceptability, ...
# Name: 30, dtype: object
# ===========================
# subj                                             Ketamine
# rel                                                   Has
# obj     Active metabolite (hydroxynorketamine) that ca...
# Name: 31, dtype: object
# ---------------------------
# Unnamed: 0                              4
# subj          Escitalopram and Sertraline
# rel                      Highly effective
# obj             Unipolar major depression
# Name: 31, dtype: object
# ===========================
# subj    Depression-focused psychotherapy
# rel      Second most common treatment of
# obj               Acute phase depression
# Name: 32, dtype: object
# ---------------------------
# Unnamed: 0                                      5
# subj                  Escitalopram and Sertraline
# rel                          first-line treatment
# obj           Moderate to severe major depression
# Name: 32, dtype: object
# ===========================
# subj    Depression-focused psychotherapy
# rel                                  For
# obj                 Mild to moderate MDD
# Name: 34, dtype: object
# ---------------------------
# Unnamed: 0                                                    0
# subj                                  Major Depressive Disorder
# rel                                                  Definition
# obj           a prevalent psychiatric disorder leading to po...
# Name: 34, dtype: object
# ===========================
# subj                     Depression-focused psychotherapy
# rel                                                  Goal
# obj     To monitor their mood, improve their functioni...
# Name: 36, dtype: object
# ---------------------------
# Unnamed: 0                                                    2
# subj                       Monoamine Oxidase Inhibitors (MAOIs)
# rel                                          Less commonly used
# obj           due to side effects such as hepatotoxicity and...
# Name: 36, dtype: object
# ===========================
# subj                     Depression-focused psychotherapy
# rel                                               Entails
# obj     Cognitive-behavioral therapy (CBT), interperso...
# Name: 37, dtype: object
# ---------------------------
# Unnamed: 0                                                    3
# subj                           Tricyclic antidepressants (TCAs)
# rel                                         More effective than
# obj           SSRIs in hospitalized patients with severe Maj...
# Name: 37, dtype: object
# ===========================
# subj                         Cognitive-behavioral therapy
# rel                                                   For
# obj     Depressed patients’ with irrational beliefs an...
# Name: 38, dtype: object
# ---------------------------
# Unnamed: 0                                                    4
# subj                                                   Ketamine
# rel                                                      Treats
# obj           resistant unipolar and possibly bipolar depres...
# Name: 38, dtype: object
# ===========================
# subj    Acceptance and commitment therapy
# rel                              Based on
# obj              Functional contextualism
# Name: 41, dtype: object
# ---------------------------
# Unnamed: 0                                             7
# subj                  Cognitive-Behavioral Therapy (CBT)
# rel                                 first-line treatment
# obj           Mild to Moderate Major Depressive Disorder
# Name: 41, dtype: object
# ===========================
# subj                    Acceptance and commitment therapy
# rel                                                   Use
# obj     Reduce depressive symptoms and preventing relapse
# Name: 42, dtype: object
# ---------------------------
# Unnamed: 0                                             8
# subj                         Interpersonal Therapy (IPT)
# rel                                 first-line treatment
# obj           Mild to Moderate Major Depressive Disorder
# Name: 42, dtype: object
# ===========================
# subj                 Acceptance and commitment therapy
# rel                                                Use
# obj     Accepting and adjusting to persistent problems
# Name: 43, dtype: object
# ---------------------------
# Unnamed: 0                                                9
# subj                                               Exercise
# rel                                             Recommended
# obj           as adjunct to treat Major Depressive Disorder
# Name: 43, dtype: object
# ===========================
# subj                                    Schema Therapy
# rel                                             Treats
# obj     Patients with personality disorder comorbidity
# Name: 47, dtype: object
# ---------------------------
# Unnamed: 0                                                2
# subj                                             Sertraline
# rel                                    first-line treatment
# obj           Moderate to severe major depression in adults
# Name: 47, dtype: object
# ===========================
# subj                       Interpersonal Therapy
# rel                                         Goal
# obj     Identify triggers of depression episodes
# Name: 48, dtype: object
# ---------------------------
# Unnamed: 0                                              3
# subj                       New-generation antidepressants
# rel                                       Associated with
# obj           Inconsistency in results regarding efficacy
# Name: 48, dtype: object
# ===========================
# subj                              Problem-solving therapy
# rel                                                  Goal
# obj     Combines cognitive and interpersonal elements,...
# Name: 50, dtype: object
# ---------------------------
# Unnamed: 0                                      5
# subj                  Sertraline and Escitalopram
# rel                              Highly effective
# obj           Acute treatment of major depression
# Name: 50, dtype: object
# ===========================
# subj                              Problem-solving therapy
# rel                                                   Use
# obj     Preventing depression among the elderly and tr...
# Name: 51, dtype: object
# ---------------------------
# Unnamed: 0                                                    6
# subj                                               Escitalopram
# rel                                               Comparable to
# obj           Sertraline in terms of efficacy and acceptabil...
# Name: 51, dtype: object
# ===========================
# subj                           Marital and family therapy
# rel                                                Treats
# obj     Severe forms of depression associated with med...
# Name: 52, dtype: object
# ---------------------------
# Unnamed: 0                                                0
# subj                                             Depression
# rel                                         Associated with
# obj           poor quality of life and impaired functioning
# Name: 52, dtype: object
# ===========================
# subj               Marital and family therapy
# rel                                       Use
# obj     Resolving marital and family problems
# Name: 54, dtype: object
# ---------------------------
# Unnamed: 0                                   2
# subj          Depression-focused psychotherapy
# rel                      second-line treatment
# obj                                 Depression
# Name: 54, dtype: object
# ===========================
# subj                           Marital and family therapy
# rel                                                  Goal
# obj     Facilitate communication and resolve different...
# Name: 55, dtype: object
# ---------------------------
# Unnamed: 0                                  3
# subj          Electroconvulsive therapy (ECT)
# rel                          Highly effective
# obj                                Depression
# Name: 55, dtype: object
# ===========================
# subj                                Psychodynamic therapy
# rel                                               Focuses
# obj     Intrapsychic conflicts related to shame, repre...
# Name: 58, dtype: object
# ---------------------------
# Unnamed: 0                              6
# subj                                SSRIs
# rel                          side effects
# obj           sexual and digestive issues
# Name: 58, dtype: object
# ===========================
# subj          Group therapy
# rel                 Reduces
# obj     Depressive Symptoms
# Name: 59, dtype: object
# ---------------------------
# Unnamed: 0                                                    7
# subj                                                   Ketamine
# rel                                                side effects
# obj           dizziness, neurotoxicity, cognitive dysfunctio...
# Name: 59, dtype: object
# ===========================
# subj            Mindfulness-based cognitive therapy
# rel                                        Combines
# obj     CBT with mindfulness-based stress reduction
# Name: 60, dtype: object
# ---------------------------
# Unnamed: 0                                     8
# subj          Cognitive-Behavioral Therapy (CBT)
# rel                         first-line treatment
# obj                                   Depression
# Name: 60, dtype: object
# ===========================
# subj                  Mindfulness-based cognitive therapy
# rel                                                  Goal
# obj     Reduce, or even stop, antidepressant treatment...
# Name: 61, dtype: object
# ---------------------------
# Unnamed: 0                              9
# subj          Interpersonal Therapy (IPT)
# rel                  first-line treatment
# obj                            Depression
# Name: 61, dtype: object
# ===========================
# subj                                     Psycho-education
# rel                                                  Goal
# obj     Educates depressed patients and family members...
# Name: 62, dtype: object
# ---------------------------
# Unnamed: 0                                                    0
# subj                                           Major Depression
# rel                                                  Definition
# obj           a mental health disorder characterized by a pe...
# Name: 62, dtype: object
# ===========================
# subj                                     Psycho-education
# rel                                                  Goal
# obj     Addresses Issues such as misperceptions about ...
# Name: 63, dtype: object
# ---------------------------
# Unnamed: 0                                      1
# subj            Second-generation antidepressants
# rel                               Associated with
# obj           inconsistencies in efficacy results
# Name: 63, dtype: object
# ===========================
# subj                        Physical Exercise
# rel                                  Benefits
# obj     Improvements in one’s quality of life
# Name: 64, dtype: object
# ---------------------------
# Unnamed: 0                                                    2
# subj          Mirtazapine, Escitalopram, Venlafaxine, and Se...
# rel                                              More effective
# obj           than Duloxetine, Fluoxetine, Fluvoxamine, Paro...
# Name: 64, dtype: object
# ===========================
# subj                                 Physical Exercise
# rel                                            Finding
# obj     an adjunct to other Anti-depressive treatments
# Name: 65, dtype: object
# ---------------------------
# Unnamed: 0                                                    3
# subj                                                 Reboxetine
# rel                                              Less effective
# obj           than all the other tested antidepressants for ...
# Name: 65, dtype: object
# ===========================
# subj                        Acute-phase treatment options
# rel                                            Approaches
# obj     Pharmacotherapy, depression-focused psychother...
# Name: 66, dtype: object
# ---------------------------
# Unnamed: 0                                                    4
# subj                                Escitalopram and Sertraline
# rel                                                  Properties
# obj           Show the best profile of acceptability, leadin...
# Name: 66, dtype: object
# ===========================
# subj                                   Somatic treatments
# rel                                              Includes
# obj     Transcranial magnetic stimulation (rTMS), tran...
# Name: 67, dtype: object
# ---------------------------
# Unnamed: 0                                                    5
# subj                                                 Sertraline
# rel                                               Comparable to
# obj           Escitalopram in terms of balance between benef...
# Name: 67, dtype: object
# ===========================
# subj                       Electroconvulsive therapy
# rel                                        Effective
# obj     Acute phase of depression in some situations
# Name: 68, dtype: object
# ---------------------------
# Unnamed: 0                                                6
# subj          Acute treatment duration for Major Depression
# rel                                              Definition
# obj                                 8-week treatment period
# Name: 68, dtype: object
# ===========================
# subj          Electroconvulsive therapy
# rel                             Reduces
# obj     Number of hospital readmissions
# Name: 69, dtype: object
# ---------------------------
# Unnamed: 0                                                    0
# subj                                  Major Depressive Disorder
# rel                                                  Definition
# obj           a prevalent psychiatric disorder leading to po...
# Name: 69, dtype: object
# ===========================
# subj           Electroconvulsive therapy
# rel                                 Goal
# obj     Lighten the burden of depression
# Name: 70, dtype: object
# ---------------------------
# Unnamed: 0                                                   1
# subj           Selective Serotonin Reuptake Inhibitors (SSRIs)
# rel                                       first-line treatment
# obj           Major Depressive Disorder during the acute phase
# Name: 70, dtype: object
# ===========================
# subj                            Electroconvulsive therapy
# rel                                          Eligible for
# obj     Patients with severe and psychotic depression,...
# Name: 71, dtype: object
# ---------------------------
# Unnamed: 0                                                2
# subj                              Major Depressive Disorder
# rel                                                 Symptom
# obj           high rates of suicidal behavior and mortality
# Name: 71, dtype: object
# ===========================
# subj    Repetitive Transcranial magnetic stimulation
# rel                                          Results
# obj          rTMS and antidepressants more effective
# Name: 73, dtype: object
# ---------------------------
# Unnamed: 0                                  4
# subj          Electroconvulsive therapy (ECT)
# rel                          highly effective
# obj            somatic therapy for Depression
# Name: 73, dtype: object
# ===========================
# subj              Transcranial direct current stimulation
# rel                                               Entails
# obj     Weak currents delivered to the brain via elect...
# Name: 74, dtype: object
# ---------------------------
# Unnamed: 0                                       5
# subj          Monoamine Oxidase Inhibitors (MAOIs)
# rel                             less commonly used
# obj                                antidepressants
# Name: 74, dtype: object
# ===========================
# subj        Transcranial direct current stimulation
# rel                                         Results
# obj     Lower than that of antidepressants and rTMS
# Name: 77, dtype: object
# ---------------------------
# Unnamed: 0                                            8
# subj                                           Ketamine
# rel                       specific efficacy in treating
# obj           resistant unipolar and bipolar depression
# Name: 77, dtype: object
# ===========================
# subj                             Magnetic Seizure Therapy
# rel                                               Entials
# obj     Inducing a therapeutic seizure by applying mag...
# Name: 80, dtype: object
# ---------------------------
# Unnamed: 0                                                    0
# subj          Mirtazapine, escitalopram, venlafaxine, sertra...
# rel                                              More effective
# obj           duloxetine, fluoxetine, fluvoxamine, paroxetin...
# Name: 80, dtype: object
# ===========================
# subj                                           Luxtherapy
# rel                                          Eligible for
# obj     Those with seasonal and non-seasonal depressio...
# Name: 81, dtype: object
# ---------------------------
# Unnamed: 0                                                  1
# subj                              Escitalopram and sertraline
# rel                                            More tolerable
# obj           duloxetine, fluvoxamine, paroxetine, reboxetine
# Name: 81, dtype: object
# ===========================
# subj                                  Fluoxetine
# rel                                 Side effects
# obj     Generally acceptable side effect profile
# Name: 83, dtype: object
# ---------------------------
# Unnamed: 0                3
# subj             Sertraline
# rel           Comparable to
# obj            escitalopram
# Name: 83, dtype: object
# ===========================
# subj               Fluoxetine
# rel     Moderate efficacy for
# obj                   Anxiety
# Name: 84, dtype: object
# ---------------------------
# Unnamed: 0                                      4
# subj                     Mirtazapine, venlafaxine
# rel                              Highly effective
# obj           Major depressive disorder treatment
# Name: 84, dtype: object
# ===========================
# subj                                         Fluoxetine
# rel                                 High efficiency for
# obj     Obsessive-compulsive disorder, bulimia nerviosa
# Name: 85, dtype: object
# ---------------------------
# Unnamed: 0                                          5
# subj                                       Sertraline
# rel                                       Widely used
# obj           Treatment for Major depressive disorder
# Name: 85, dtype: object
# ===========================
# subj             Duloxetine
# rel            Side effects
# obj     Lower acceptability
# Name: 86, dtype: object
# ---------------------------
# Unnamed: 0                                   6
# subj                                Reboxetine
# rel                             Less effective
# obj           All the other 11 antidepressants
# Name: 86, dtype: object
# ===========================
# subj                                 Duloxetine
# rel                         High efficiency for
# obj     Neuropathic pain, fibromyalgia, anxiety
# Name: 87, dtype: object
# ---------------------------
# Unnamed: 0                                                  7
# subj                                               Reboxetine
# rel                                             Not effective
# obj           First-line acute treatment for major depression
# Name: 87, dtype: object
# ===========================
# subj           Depression
# rel           Side effect
# obj     Suicidal behavior
# Name: 88, dtype: object
# ---------------------------
# Unnamed: 0                                                  0
# subj          Selective Serotonin Reuptake Inhibitors (SSRIs)
# rel                                      first-line treatment
# obj                                            All Depression
# Name: 88, dtype: object
# ===========================
# subj     Depression
# rel     Side effect
# obj       Mortality
# Name: 89, dtype: object
# ---------------------------
# Unnamed: 0                                  1
# subj          Electroconvulsive therapy (ECT)
# rel                            most effective
# obj            somatic therapy for depression
# Name: 89, dtype: object
# ===========================
# subj                      Depression
# rel                      Side effect
# obj     Slower response to treatment
# Name: 90, dtype: object
# ---------------------------
# Unnamed: 0                                    2
# subj                                      MAOIs
# rel               Specific efficacy in treating
# obj           depression with atypical features
# Name: 90, dtype: object
# ===========================
# subj              Pharmacotherapy
# rel                        Treats
# obj     Acute phase of depression
# Name: 91, dtype: object
# ---------------------------
# Unnamed: 0                                          3
# subj                                        Bupropion
# rel                                        Properties
# obj           minimal weight gain or even weight loss
# Name: 91, dtype: object
# ===========================
# subj    Pharmacotherapy
# rel             Entails
# obj                TCAs
# Name: 94, dtype: object
# ---------------------------
# Unnamed: 0                                             6
# subj                                       Psychotherapy
# rel                                 first-line treatment
# obj           mild to moderate Major Depressive Disorder
# Name: 94, dtype: object
# ===========================
# subj                       Pharmacotherapy
# rel                                Entails
# obj     Norepinephrine reuptake inhibitors
# Name: 95, dtype: object
# ---------------------------
# Unnamed: 0                                                    7
# subj          Cognitive Behavioral Therapy (CBT) and Interpe...
# rel                                        first-line treatment
# obj                  mild to moderate Major Depressive Disorder
# Name: 95, dtype: object
# ===========================
# subj    Pharmacotherapy
# rel             Entails
# obj            Ketamine
# Name: 96, dtype: object
# ---------------------------
# Unnamed: 0                                8
# subj          Vagus Nerve Stimulation (VNS)
# rel                       treatment options
# obj                    resistant depression
# Name: 96, dtype: object
# ===========================
# subj              Monoamine oxidase inhibitors
# rel                               Side effects
# obj     Hepatotoxicity and hypertensive crises
# Name: 97, dtype: object
# ---------------------------
# Unnamed: 0                                                 9
# subj                                       Physical exercise
# rel                                           recommendation
# obj           as adjunct to other anti-depressive treatments
# Name: 97, dtype: object
# ===========================
# subj    Monoamine oxidase inhibitors
# rel                 Same efficacy as
# obj        Tricyclic antidepressants
# Name: 98, dtype: object
# ---------------------------
# Unnamed: 0                                                   10
# subj                 Mindfulness-Based Cognitive Therapy (MBCT)
# rel                                       Potential alternative
# obj            to reduce or even stop antidepressant treatme...
# Name: 98, dtype: object
# ===========================
# subj                        SSRIs
# rel                         Treat
# obj     Acute phase of depression
# Name: 102, dtype: object
# ---------------------------
# Unnamed: 0                                       2
# subj                                    Reboxetine
# rel                                 Less effective
# obj           all the other antidepressants tested
# Name: 102, dtype: object
# ===========================
# subj                                                 SSRI
# rel                                              Includes
# obj     fluoxetine, sertraline, paroxetine, fluvoxamin...
# Name: 104, dtype: object
# ---------------------------
# Unnamed: 0                4
# subj             Sertraline
# rel           Comparable to
# obj            Escitalopram
# Name: 104, dtype: object
# ===========================
# subj      Norepinephrine reuptake inhibitors
# rel                             Eligible for
# obj     Patients who do not respond to SSRIs
# Name: 105, dtype: object
# ---------------------------
# Unnamed: 0                                                    5
# subj                                                 Reboxetine
# rel                                               Not effective
# obj           routine first-line acute treatment for major d...
# Name: 105, dtype: object
# ===========================
# subj                              Trazodone
# rel                                     Use
# obj     In low doses as a sedative hypnotic
# Name: 106, dtype: object
# ---------------------------
# Unnamed: 0                                                    6
# subj                                  Duloxetine and Paroxetine
# rel                                                Side effects
# obj           less well tolerated than Escitalopram and Sert...
# Name: 106, dtype: object
# ===========================
# subj                                           Nefazodone
# rel                                          Side effects
# obj     Rare cases of clinical idiosyncratic hepatotox...
# Name: 108, dtype: object
# ---------------------------
# Unnamed: 0                                                    0
# subj                                         Anxious depression
# rel                                                  Definition
# obj           Major depressive disorder with clinically mean...
# Name: 108, dtype: object
# ===========================
# subj                                         Bupropion
# rel                                         Properties
# obj     Norepinephrine and dopamine reuptake inhibitor
# Name: 109, dtype: object
# ---------------------------
# Unnamed: 0                                                    1
# subj                                         Anxious depression
# rel                                                     Symptom
# obj           greater severity of depressive illness, greate...
# Name: 109, dtype: object
# ===========================
# subj                                            Bupropion
# rel                                            Properties
# obj     Has a more activating profile than SSRIs that ...
# Name: 110, dtype: object
# ---------------------------
# Unnamed: 0                                                    2
# subj                                         Anxious depression
# rel                                            More common than
# obj           nonanxious depression in African American grou...
# Name: 110, dtype: object
# ===========================
# subj                                            Bupropion
# rel                                            Properties
# obj     A better tolerability than SSRIs, with minimal...
# Name: 111, dtype: object
# ---------------------------
# Unnamed: 0                                                    3
# subj                                         Anxious depression
# rel                                                Side effects
# obj           greater reduction in anxiety/somatization scor...
# Name: 111, dtype: object
# ===========================
# subj                                            Bupropion
# rel                                               Finding
# obj     Is more likely than SSRIs to improve symptoms ...
# Name: 112, dtype: object
# ---------------------------
# Unnamed: 0                                                    4
# subj                                         Anxious depression
# rel                                                side effects
# obj           high mean QIDS-SR score at exit, low raw QID-S...
# Name: 112, dtype: object
# ===========================
# subj                                            Mianserin
# rel                                            Properties
# obj     Antagonizes serotoninergic subtypes receptors,...
# Name: 113, dtype: object
# ---------------------------
# Unnamed: 0                            5
# subj                         Citalopram
# rel                first-line treatment
# obj           Major depressive disorder
# Name: 113, dtype: object
# ===========================
#
# Overall Similarity Score: 35.48275862068966
# These are the mismatches: 84

# %% [markdown]
# ## TF- IDF Vector and Cosine Method

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
#cosine method is good for when the length of the comparisons don't matter- the content is more emphasized

# %%
ground_truth = pd.read_csv("Annotations.csv")
llm_file =  pd.read_csv("Temperature1_WithoutExamples_cleaned.csv")

# turn the rows into a single string
ground_truth['combined'] = ground_truth.astype(str).agg(' '.join, axis=1)
llm_file['combined'] = llm_file.astype(str).agg(' '.join, axis=1)

# vectorize
vectorizer = TfidfVectorizer()
ground_truth_tfidf = vectorizer.fit_transform(ground_truth['combined'])
llm_tfidf = vectorizer.transform(llm_file['combined'])

# compares each row of the ground truth to each row of the llm file
similarity_matrix = cosine_similarity(ground_truth_tfidf, llm_tfidf)

# extract the row in the llm output with the highest similarity 
highest_sim = similarity_matrix.max(axis=1)
highest_sim_index = similarity_matrix.argmax(axis=1)

# llm_file = llm_file.reset_index(drop=True)
result = pd.DataFrame({
    'ground_truth_row': ground_truth['combined'],
    'most_similar_row': llm_file['combined'].iloc[highest_sim_index].apply(lambda x: x).values,
    'similarity_score': highest_sim
})


result.to_csv('similarity_results.csv', index=False)

print(result)
print(result['similarity_score'].mean())
# Out:
#                                       ground_truth_row  \
# 0             Depression Side effect Suicidal behavior
# 1                     Depression Side effect Mortality
# 2    Depression Side effect Slower response to trea...
# 3     Pharmacotherapy Treats Acute phase of depression
# 4                        Pharmacotherapy Entails SSRIs
# ..                                                 ...
# 171  Fluoxetine Side effects Generally acceptable s...
# 172           Fluoxetine Moderate efficacy for Anxiety
# 173  Fluoxetine High efficiency for  Obsessive-comp...
# 174       Duloxetine Side effects Lower acceptability
# 175  Duloxetine High efficiency for  Neuropathic pa...
#
#                                       most_similar_row  similarity_score
# 0    5 All Depression Associated with high rates of...          0.531832
# 1    5 All Depression Associated with high rates of...          0.351954
# 2    6 Acute treatment duration for Major Depressio...          0.304288
# 3        3 Electroconvulsive therapy Treats Depression          0.416074
# 4     6 SSRIs side effects sexual and digestive issues          0.228735
# ..                                                 ...               ...
# 171   6 SSRIs side effects sexual and digestive issues          0.334444
# 172  3 Anxious depression Side effects greater redu...          0.335467
# 173  5 Sertraline Widely used Treatment for Major d...          0.237272
# 174  6 Duloxetine and Paroxetine Side effects less ...          0.366347
# 175  3 Anxious depression Side effects greater redu...          0.234134
#
# [176 rows x 3 columns]
# 0.36279207898135996

# %% [markdown]
# ## GPT Critic

# %%
import concurrent.futures
import re
import openai
import pandas as pd

openai.api_key = ''

# Load data
llm_output = pd.read_csv("Temperature1_WithoutExamples_cleaned.csv")
ground_truth = pd.read_csv("Annotations.csv")

# Score extraction with regex
def extract_score(evaluation):
    match = re.search(r'(?:Overall correctness score|Score|I would score the LLM output a)[:\s]*([0-1](?:\.\d+)?)', evaluation, re.IGNORECASE)
    
    if match:
        return float(match.group(1))
    else:
        partial_match = re.search(r'correctness.*?([0-1](?:\.\d+)?)', evaluation, re.IGNORECASE)
        if partial_match:
            return float(partial_match.group(1))
        
        print(f"Failed to extract score from evaluation: {evaluation}")
        return -1

# Relevance check
def is_relevant(ground_truth, llm_output):
    gt_terms = set(ground_truth.lower().split())
    llm_terms = set(llm_output.lower().split())
    relevance = gt_terms.intersection(llm_terms)
    return len(relevance) > 1

# Create prompt for OpenAI GPT model
def create_prompt(ground_truth_row, llm_output_row):
    prompt = f"""
    I want you to compare the following statements.

    Ground Truth: {ground_truth_row}
    
    LLM Output: {llm_output_row}
    
    Based on the ground truth, evaluate the correctness of the LLM output in terms of:
    1. Factual correctness: Are the facts in the LLM output correct compared to the ground truth?
    2. Omissions: Does the LLM output miss any key details present in the ground truth?
    3. Contradictions: Does the LLM output contradict any information in the ground truth?

    You are required to provide a score from 0 to 1 for overall correctness (1 being highly correct), and include a short explanation of the result.
    """
    return prompt

# Get evaluation from GPT model
def get_critic_gpt_evaluation(prompt):
    try:
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",  
            messages=[{"role": "user", "content": prompt}],
            max_tokens=150
        )
        return response['choices'][0]['message']['content'].strip()
    except Exception as e:
        print(f"Error during evaluation: {e}")
        return None

# Evaluate a single ground truth row against LLM output
def evaluate_row(gt_row, llm_output):
    best_evaluation = None
    best_llm_row = None
    best_score = -1
    irrelevant_flag = False

    for j in range(len(llm_output)):
        llm_subj = llm_output.loc[j, 'subj']
        llm_rel = llm_output.loc[j, 'rel']
        llm_obj = llm_output.loc[j, 'obj']
        llm_row = f"{llm_subj} {llm_rel} {llm_obj}"
        
        if not is_relevant(gt_row, llm_row):
            irrelevant_flag = True
            continue     

        prompt = create_prompt(gt_row, llm_row)
        evaluation = get_critic_gpt_evaluation(prompt)

        if evaluation:
            score = extract_score(evaluation)
            if score == -1:
                print(f"Score extraction failed for Ground Truth: '{gt_row}' and LLM Output: '{llm_row}'\nFull Evaluation: {evaluation}")
            else:
                print(f"Evaluation for Ground Truth: '{gt_row}' and LLM Output: '{llm_row}' resulted in score: {score}")

            if score > best_score:
                best_score = score
                best_evaluation = evaluation
                best_llm_row = llm_row
    
    if best_llm_row and best_evaluation:
        return {
            'ground_truth': gt_row,
            'best_llm_output': best_llm_row,
            'best_evaluation': best_evaluation
        }
    elif irrelevant_flag:
        print(f"No relevant match for Ground Truth: '{gt_row}'")
        return None

# Parallel processing of ground truth rows
best_matches = []
ground_truth_rows = []

for i in range(len(ground_truth)):
    gt_subj = ground_truth.loc[i, 'subj']
    gt_rel = ground_truth.loc[i, 'rel']
    gt_obj = ground_truth.loc[i, 'obj']
    gt_row = f"{gt_subj} {gt_rel} {gt_obj}"
    ground_truth_rows.append(gt_row)

with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    future_to_row = {executor.submit(evaluate_row, gt_row, llm_output): gt_row for gt_row in ground_truth_rows}

    for future in concurrent.futures.as_completed(future_to_row):
        try:
            result = future.result()
            if result:
                best_matches.append(result)
        except Exception as e:
            print(f"Error processing a row: {e}")

# Print results
print('----------------------')
for match in best_matches:
    print(f"Ground Truth: {match['ground_truth']}")
    print(f"Best LLM Output: {match['best_llm_output']}")
    print(f"Best Evaluation: {match['best_evaluation']}")
    print('----------------------')

# Save results to DataFrame and optionally CSV
results_df = pd.DataFrame(best_matches)
print(results_df.head(10))
# results_df.to_csv('comparison_results.csv', index=False)
# Out:
# No relevant match for Ground Truth: 'Pharmacotherapy Entails SSRIs'
# No relevant match for Ground Truth: 'Pharmacotherapy Entails TCAs'
# No relevant match for Ground Truth: 'Pharmacotherapy Entails Ketamine '
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Same efficacy as Tricyclic antidepressants' and LLM Output: 'Monoamine Oxidase Inhibitors Less commonly used Major Depressive Disorder' resulted in score: 0.5
# Evaluation for Ground Truth: 'Depression Side effect Suicidal behavior' and LLM Output: 'Ketamine Properties very quick effects on resistant unipolar depression and acute suicidal ideation' resulted in score: 0.8
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'All Depression Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning' resulted in score: 0.5
# Evaluation for Ground Truth: 'Depression Side effect Mortality' and LLM Output: 'All Depression Associated with high rates of suicidal behavior and mortality' resulted in score: 0.75
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Monoamine Oxidase Inhibitors Less commonly used Major Depressive Disorder' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Monoamine Oxidase Inhibitors Less commonly used Major Depressive Disorder' resulted in score: 0.5
# Evaluation for Ground Truth: 'Pharmacotherapy Entails Norepinephrine reuptake inhibitors' and LLM Output: 'Selective Serotonin Reuptake Inhibitors (SSRIs) first-line treatment All Depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Major Depressive Disorder Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning' resulted in score: 0.3
# Evaluation for Ground Truth: 'Pharmacotherapy Entails Monoamine oxidase inhibitors' and LLM Output: 'Monoamine Oxidase Inhibitors Less commonly used Major Depressive Disorder' resulted in score: 0.5
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Electroconvulsive therapy Treats Depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Monoamine Oxidase Inhibitors Less commonly used Major Depressive Disorder' resulted in score: 0.5Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Same efficacy as Tricyclic antidepressants' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) Less commonly used due to side effects such as hepatotoxicity and hypertensive crisis' resulted in score: 0.5
#
# Evaluation for Ground Truth: 'Depression Side effect Mortality' and LLM Output: 'Anxious depression Side effects greater reduction in anxiety/somatization score yet greater residual symptoms of anxiety/somatization than nonanxious depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Depression Side effect Suicidal behavior' and LLM Output: 'All Depression Associated with high rates of suicidal behavior and mortality' resulted in score: 0.5
# Evaluation for Ground Truth: 'Pharmacotherapy Entails Norepinephrine reuptake inhibitors' and LLM Output: 'Selective Serotonin Reuptake Inhibitors (SSRIs) first-line treatment Major Depressive Disorder' resulted in score: 0.25
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Escitalopram and Sertraline Overview Good balance between benefits, acceptability, and acquisition cost for moderate to severe major depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Selective Serotonin Reuptake Inhibitors (SSRIs) first-line treatment All Depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Combination of medication, psychotherapy, and somatic therapy Treats resistant form of depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Ketamine Side effects dizziness, neurotoxicity, cognitive dysfunction, blurred vision, psychosis, dissociation, urological dysfunction, restlessness, headache, nausea, vomiting, and cardiovascular symptoms' resulted in score: 0.2
# Evaluation for Ground Truth: 'Pharmacotherapy Entails Monoamine oxidase inhibitors' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) Less commonly used due to side effects such as hepatotoxicity and hypertensive crisis' resulted in score: 0.7
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Physical exercise Associated with improvement in depression symptom and prevention of relapses' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Same efficacy as Tricyclic antidepressants' and LLM Output: 'Tricyclic antidepressants (TCAs) More effective than SSRIs in hospitalized patients with severe Major Depressive Disorder symptoms' resulted in score: 0.5Evaluation for Ground Truth: 'Depression Side effect Mortality' and LLM Output: 'Anxious depression side effects high mean QIDS-SR score at exit, low raw QID-SR change score, low percentage change in QIDS-SR score than nonanxious depression' resulted in score: 0.5
#
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Ketamine Properties very quick effects on resistant unipolar depression and acute suicidal ideation' resulted in score: 0.0
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Vagus Nerve Stimulation Treats resistant unilateral or bipolar depression' resulted in score: 0.0
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) Less commonly used due to side effects such as hepatotoxicity and hypertensive crisis' resulted in score: 0.75
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'All Depression Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning' resulted in score: 0.2
# Evaluation for Ground Truth: 'Pharmacotherapy Entails Monoamine oxidase inhibitors' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) less commonly used antidepressants' resulted in score: 0.75Evaluation for Ground Truth: 'Depression Side effect Suicidal behavior' and LLM Output: 'Major Depressive Disorder Symptom high rates of suicidal behavior and mortality' resulted in score: 0.75
#
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Depression-focused psychotherapy second-line treatment All Depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Pharmacotherapy Entails Norepinephrine reuptake inhibitors' and LLM Output: 'Selective Serotonin Reuptake Inhibitors (SSRIs) first-line treatment Depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Depression Side effect Mortality' and LLM Output: 'Anxious depression Less commonly used adequate dose of citalopram due to side effects or patient’s choice' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Ketamine Side effects dizziness, neurotoxicity, cognitive dysfunction, blurred vision, psychosis, dissociation, urological dysfunction, restlessness, headache, nausea, vomiting, and cardiovascular symptoms' resulted in score: 0.2
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Same efficacy as Tricyclic antidepressants' and LLM Output: 'New-generation antidepressants Associated with Inconsistency in results regarding efficacy' resulted in score: 0.5
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Physical exercise Associated with improvement in depression symptom and prevention of relapses' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Reboxetine less effective All other tested antidepressants for Unipolar Major Depression in adults' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Electroconvulsive therapy (ECT) Highly effective somatic therapy for depression in some specific situations' resulted in score: 0.2
# Evaluation for Ground Truth: 'Pharmacotherapy Entails Norepinephrine reuptake inhibitors' and LLM Output: 'Selective Serotonin Reuptake Inhibitors (SSRIs) first-line treatment Major Depressive Disorder during the acute phase' resulted in score: 0.2
# Evaluation for Ground Truth: 'SSRIs Is a part of Pharmacotherapy' and LLM Output: 'Major Depressive Disorder Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning' resulted in score: 0.5
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Combination of medication, psychotherapy, and somatic therapy Treats resistant form of depression' resulted in score: 0.0
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Cognitive Behavioral Therapy and Interpersonal Therapy first-line treatment Mild to moderate Major Depressive Disorder' resulted in score: 0.5
# Evaluation for Ground Truth: 'Depression Side effect Suicidal behavior' and LLM Output: 'Anxious depression Side effects greater reduction in anxiety/somatization score yet greater residual symptoms of anxiety/somatization than nonanxious depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'SSRIs Side effects sexual dysfunction, loss of appetite, vomiting, nausea, irritability, anxiety, insomnia, and headache' resulted in score: 0.5Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Same efficacy as Tricyclic antidepressants' and LLM Output: 'Second-generation antidepressants Associated with inconsistencies in efficacy results' resulted in score: 0.5
#
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Physical exercise Associated with improvement in depression symptom and prevention of relapses' resulted in score: 0.5Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Escitalopram Comparable to Sertraline in terms of efficacy and acceptability for the treatment of major depression' resulted in score: 0.5
#
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'All Depression Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning' resulted in score: 0.3
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Mirtazapine Comparable to SSRIs in efficacy' resulted in score: 0.5
# Evaluation for Ground Truth: 'Pharmacotherapy Entails Norepinephrine reuptake inhibitors' and LLM Output: 'Selective Serotonin Reuptake Inhibitors (SSRIs) first-line treatment All Depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'SSRIs Is a part of Pharmacotherapy' and LLM Output: 'All Depression Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning' resulted in score: 0.0Evaluation for Ground Truth: 'Depression Side effect Suicidal behavior' and LLM Output: 'Anxious depression side effects high mean QIDS-SR score at exit, low raw QID-SR change score, low percentage change in QIDS-SR score than nonanxious depression' resulted in score: 0.5
#
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) Less commonly used due to side effects such as hepatotoxicity and hypertensive crisis' resulted in score: 0.8
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Escitalopram and Sertraline Overview Good balance between benefits, acceptability, and acquisition cost for moderate to severe major depression' resulted in score: 0.5
# Failed to extract score from evaluation: 1. Factual correctness: The LLM output is partially correct. It correctly states that Monoamine Oxidase Inhibitors (MAOIs) are less commonly used antidepressants, which is a fact. However, it does not mention the comparison with Tricyclic antidepressants in terms of efficacy, which is a key detail present in the ground truth.
#
# 2. Omissions: The LLM output misses the key detail of comparing the efficacy of MAOIs with Tricyclic antidepressants, which is present in the ground truth. This omission is significant in terms of providing a complete and accurate understanding of the information.
#
# 3. Contradictions: The LLM output does not directly contradict any information in the ground truth.
# Score extraction failed for Ground Truth: 'Monoamine oxidase inhibitors Same efficacy as Tricyclic antidepressants' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) less commonly used antidepressants'
# Full Evaluation: 1. Factual correctness: The LLM output is partially correct. It correctly states that Monoamine Oxidase Inhibitors (MAOIs) are less commonly used antidepressants, which is a fact. However, it does not mention the comparison with Tricyclic antidepressants in terms of efficacy, which is a key detail present in the ground truth.
#
# 2. Omissions: The LLM output misses the key detail of comparing the efficacy of MAOIs with Tricyclic antidepressants, which is present in the ground truth. This omission is significant in terms of providing a complete and accurate understanding of the information.
#
# 3. Contradictions: The LLM output does not directly contradict any information in the ground truth.
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Major Depressive Disorder Definition a prevalent psychiatric disorder leading to poor quality of life and impaired functioning' resulted in score: 0.2
# Evaluation for Ground Truth: 'SSRIs  Same efficacy as TCAs' and LLM Output: 'Mirtazapine Comparable to SSRIs in efficacy' resulted in score: 0.5
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'All Depression Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning' resulted in score: 0.33
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Reboxetine Less effective than all the other tested antidepressants for treating Major Depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Ketamine Properties very quick effects on resistant unipolar depression and acute suicidal ideation' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Same efficacy as Tricyclic antidepressants' and LLM Output: 'Tricyclic antidepressants (TCAs) more effective than SSRIs in hospitalized patients' resulted in score: 0.5
# Evaluation for Ground Truth: 'Depression Side effect Suicidal behavior' and LLM Output: 'Anxious depression Less commonly used adequate dose of citalopram due to side effects or patient’s choice' resulted in score: 0.0
# Evaluation for Ground Truth: 'SSRIs Is a part of Pharmacotherapy' and LLM Output: 'Major Depressive Disorder Definition a prevalent psychiatric disorder leading to poor quality of life and impaired functioning' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Ketamine side effects dizziness, neurotoxicity, cognitive dysfunction, blurred vision, psychosis, dissociation, urological dysfunction, restlessness, headache, nausea, vomiting, and cardiovascular symptoms' resulted in score: 0.2
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Escitalopram and Sertraline first-line treatment Moderate to severe major depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Mirtazapine, Escitalopram, Venlafaxine, Sertraline More effective Duloxetine, Fluoxetine, Fluvoxamine, Paroxetine, Reboxetine' resulted in score: 0.5
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Ketamine Properties very quick effects on resistant unipolar depression and acute suicidal ideation' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Escitalopram and Sertraline Properties Show the best profile of acceptability, leading to significantly fewer discontinuations than do duloxetine, fluvoxamine, paroxetine, reboxetine, and venlafaxine' resulted in score: 0.25
# Evaluation for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Selective Serotonin Reuptake Inhibitors (SSRIs) first-line treatment All Depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Trazodone Use In low doses as a sedative hypnotic' and LLM Output: 'Major Depression Definition a mental health disorder characterized by a pervasive and persistent low mood, accompanied by low self-esteem and loss of interest or pleasure in normally enjoyable activities' resulted in score: 0.2
# Evaluation for Ground Truth: 'SSRIs Is a part of Pharmacotherapy' and LLM Output: 'SSRIs Side effects sexual dysfunction, loss of appetite, vomiting, nausea, irritability, anxiety, insomnia, and headache' resulted in score: 0.2
# Failed to extract score from evaluation: 1. Factual correctness: The LLM output discusses depression being associated with high rates of suicidal behavior and mortality, which is a factual statement. However, it does not directly address the treatment of the acute phase of depression as stated in the ground truth. Therefore, the factual correctness of the LLM output is partially correct.
#
# 2. Omissions: The LLM output misses the key detail of pharmacotherapy treating the acute phase of depression, which is present in the ground truth. This omission is significant as it does not address the specific treatment aspect mentioned in the ground truth. Therefore, the LLM output has a key omission in this regard.
#
# 3. Contradictions: The LLM output does not directly contradict the information in the ground truth.
# Score extraction failed for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'All Depression Associated with high rates of suicidal behavior and mortality'
# Full Evaluation: 1. Factual correctness: The LLM output discusses depression being associated with high rates of suicidal behavior and mortality, which is a factual statement. However, it does not directly address the treatment of the acute phase of depression as stated in the ground truth. Therefore, the factual correctness of the LLM output is partially correct.
#
# 2. Omissions: The LLM output misses the key detail of pharmacotherapy treating the acute phase of depression, which is present in the ground truth. This omission is significant as it does not address the specific treatment aspect mentioned in the ground truth. Therefore, the LLM output has a key omission in this regard.
#
# 3. Contradictions: The LLM output does not directly contradict the information in the ground truth.
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Electroconvulsive therapy Definition the most effective somatic therapy for depression in specific situations' resulted in score: 0.5
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Compared antidepressants Treatment options Acute treatment of unipolar major depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'All Depression Associated with high rates of suicidal behavior and mortality' resulted in score: 0.2
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Escitalopram and Sertraline Better acceptability Duloxetine, Fluvoxamine, Paroxetine, Reboxetine, Venlafaxine' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Sertraline Comparable to Escitalopram in terms of balance between benefits, acceptability, and acquisition cost for treating Major Depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'SSRIs side effects sexual and digestive issues' resulted in score: 0.5
# Evaluation for Ground Truth: 'Trazodone Use In low doses as a sedative hypnotic' and LLM Output: 'Anxious depression side effects high mean QIDS-SR score at exit, low raw QID-SR change score, low percentage change in QIDS-SR score than nonanxious depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Mirtazapine Comparable to SSRIs in efficacy' resulted in score: 0.33
# Evaluation for Ground Truth: 'SSRIs Is a part of Pharmacotherapy' and LLM Output: 'Major Depressive Disorder Definition a prevalent psychiatric disorder leading to poor quality of life and impaired functioning' resulted in score: 0.0
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Cognitive Behavioral Therapy and Interpersonal Therapy first-line treatment Mild to moderate Major Depressive Disorder' resulted in score: 0.2
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Physical exercise Treats All Depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Ketamine side effects dizziness, neurotoxicity, cognitive dysfunction, blurred vision, psychosis, dissociation, urological dysfunction, restlessness, headache, nausea, vomiting, and cardiovascular symptoms' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) less commonly used antidepressants' resulted in score: 0.33
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) Less commonly used due to side effects such as hepatotoxicity and hypertensive crisis' resulted in score: 0.5Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Selective Serotonin Reuptake Inhibitor antidepressants first-line treatment Major Depressive Disorder during the acute phase' resulted in score: 0.8
#
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Escitalopram and Sertraline Overview Good balance between benefits, acceptability, and acquisition cost for moderate to severe major depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Escitalopram and Sertraline Overview Good balance between benefits, acceptability, and acquisition cost for moderate to severe major depression' resulted in score: 0.2
# Evaluation for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Escitalopram and Sertraline Overview Good balance between benefits, acceptability, and acquisition cost for moderate to severe major depression' resulted in score: 0.4
# Evaluation for Ground Truth: 'Nefazodone Is comparable to  SSRI' and LLM Output: 'Mirtazapine Comparable to SSRIs in efficacy' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Interpersonal therapy (IPT) Comparable to CBT for mild to moderate major depressive episodes in adults' resulted in score: 0.2
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) less commonly used antidepressants' resulted in score: 0.5
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Escitalopram and Sertraline Highly effective Unipolar major depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Selective Serotonin Reuptake Inhibitor antidepressants first-line treatment Major Depressive Disorder during the acute phase' resulted in score: 0.75
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Cognitive-Behavioral Therapy (CBT) first-line treatment Mild to Moderate Major Depressive Disorder' resulted in score: 0.5
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Resistant forms of depression Treats Combination of medication, psychotherapy, and somatic therapy' resulted in score: 0.4
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Escitalopram and Sertraline first-line treatment Moderate to severe major depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'SSRIs side effects sexual and digestive issues, irritability, anxiety, insomnia, and headaches' resulted in score: 0.0
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Escitalopram and Sertraline first-line treatment Moderate to severe major depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Nefazodone Is comparable to  SSRI' and LLM Output: 'Escitalopram Comparable to Sertraline in terms of efficacy and acceptability for the treatment of major depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Selective Serotonin Reuptake Inhibitors (SSRIs) first-line treatment Major Depressive Disorder' resulted in score: 0.5
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Resistant forms of depression Treats Combination of medication, psychotherapy, and somatic therapy' resulted in score: 0.5
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Interpersonal Therapy (IPT) first-line treatment Mild to Moderate Major Depressive Disorder' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Reboxetine Not effective First-line acute treatment for major depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Major Depressive Disorder Definition a prevalent psychiatric disorder leading to poor quality of life and impaired functioning' resulted in score: 0.2
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Escitalopram and Sertraline Side effects significantly fewer discontinuations' resulted in score: 0.5Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'SSRIs Side effects sexual dysfunction, loss of appetite, vomiting, nausea, irritability, anxiety, insomnia, and headache' resulted in score: 0.5
#
# Evaluation for Ground Truth: 'Nefazodone Is comparable to  SSRI' and LLM Output: 'Sertraline Comparable to Escitalopram in terms of balance between benefits, acceptability, and acquisition cost for treating Major Depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Mirtazapine, Escitalopram, Venlafaxine, Sertraline More effective Duloxetine, Fluoxetine, Fluvoxamine, Paroxetine, Reboxetine for Unipolar Major Depression in adults' resulted in score: 0.5
# Evaluation for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) Less commonly used due to side effects such as hepatotoxicity and hypertensive crisis' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Physical exercise recommendation as adjunct to other anti-depressive treatments' resulted in score: 0.2Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Compared antidepressants Treatment options Acute treatment of unipolar major depression' resulted in score: 0.75
#
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Sertraline first-line treatment Moderate to severe major depression in adults' resulted in score: 0.5
# Evaluation for Ground Truth: 'SSRIs Is a part of Pharmacotherapy' and LLM Output: 'Major Depression Definition a mental health disorder characterized by a pervasive and persistent low mood, accompanied by low self-esteem and loss of interest or pleasure in normally enjoyable activities' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) Less commonly used due to side effects such as hepatotoxicity and hypertensive crisis' resulted in score: 0.5
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Compared antidepressants Treatment options Acute treatment of unipolar major depression' resulted in score: 0.7Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Duloxetine and Paroxetine Side effects less well tolerated than Escitalopram and Sertraline' resulted in score: 0.2
#
# Failed to extract score from evaluation: 1. Factual correctness: The LLM output is not factually correct compared to the ground truth. The ground truth mentions Norepinephrine reuptake inhibitors for patients who do not respond to SSRIs, while the LLM output talks about Tricyclic antidepressants being more effective than SSRIs in hospitalized patients with severe Major Depressive Disorder symptoms. These are two different classes of antidepressants with different indications and purposes.
#
# 2. Omissions: The LLM output misses the key detail of Norepinephrine reuptake inhibitors being eligible for patients who do not respond to SSRIs. This crucial information is not present in the LLM output.
#
# 3. Contradictions: The LLM output contradicts the information in
# Score extraction failed for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Tricyclic antidepressants (TCAs) More effective than SSRIs in hospitalized patients with severe Major Depressive Disorder symptoms'
# Full Evaluation: 1. Factual correctness: The LLM output is not factually correct compared to the ground truth. The ground truth mentions Norepinephrine reuptake inhibitors for patients who do not respond to SSRIs, while the LLM output talks about Tricyclic antidepressants being more effective than SSRIs in hospitalized patients with severe Major Depressive Disorder symptoms. These are two different classes of antidepressants with different indications and purposes.
#
# 2. Omissions: The LLM output misses the key detail of Norepinephrine reuptake inhibitors being eligible for patients who do not respond to SSRIs. This crucial information is not present in the LLM output.
#
# 3. Contradictions: The LLM output contradicts the information in
# Failed to extract score from evaluation: 1. Factual correctness: The LLM output is not factually correct compared to the ground truth. Reboxetine is mentioned in the LLM output, but it is not directly related to the information about monoamine oxidase inhibitors and their eligibility for patients who do not respond to other treatments. Therefore, the factual correctness is lacking in the LLM output.
# 2. Omissions: The LLM output misses key details present in the ground truth. It does not provide information about monoamine oxidase inhibitors or their use for patients who do not respond to other treatments, which is a significant omission.
# 3. Contradictions: The LLM output does not necessarily contradict the information in the ground truth since it does not provide conflicting information, but
# Score extraction failed for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Reboxetine Not effective routine first-line acute treatment for major depression'
# Full Evaluation: 1. Factual correctness: The LLM output is not factually correct compared to the ground truth. Reboxetine is mentioned in the LLM output, but it is not directly related to the information about monoamine oxidase inhibitors and their eligibility for patients who do not respond to other treatments. Therefore, the factual correctness is lacking in the LLM output.
# 2. Omissions: The LLM output misses key details present in the ground truth. It does not provide information about monoamine oxidase inhibitors or their use for patients who do not respond to other treatments, which is a significant omission.
# 3. Contradictions: The LLM output does not necessarily contradict the information in the ground truth since it does not provide conflicting information, but
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Escitalopram and Sertraline More favorable Profile of acceptability leading to significantly fewer discontinuations than Duloxetine, Fluvoxamine, Paroxetine, Reboxetine, and Venlafaxine' resulted in score: 0.5
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Sertraline and Escitalopram Highly effective Acute treatment of major depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Nefazodone Is comparable to  SSRI' and LLM Output: 'Interpersonal therapy (IPT) Comparable to CBT for mild to moderate major depressive episodes in adults' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Exercise Recommended as adjunct to treat Major Depressive Disorder' resulted in score: 0.0
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Anxious depression Side effects greater reduction in anxiety/somatization score yet greater residual symptoms of anxiety/somatization than nonanxious depression' resulted in score: 0.0
# Evaluation for Ground Truth: 'SSRIs Is a part of Pharmacotherapy' and LLM Output: 'Major Depressive Disorder Definition a prevalent psychiatric disorder leading to poor quality of life and impaired functioning' resulted in score: 0.25
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Ketamine Treats resistant unipolar and possibly bipolar depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Sertraline and Escitalopram Highly effective Acute treatment of major depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Anxious depression side effects high mean QIDS-SR score at exit, low raw QID-SR change score, low percentage change in QIDS-SR score than nonanxious depression' resulted in score: 0.0
# Evaluation for Ground Truth: 'Bupropion Properties  Norepinephrine and dopamine reuptake inhibitor' and LLM Output: 'Selective Serotonin Reuptake Inhibitor antidepressants first-line treatment Major Depressive Disorder' resulted in score: 0.0
# Evaluation for Ground Truth: 'Nefazodone Side effects Rare cases of clinical idiosyncratic hepatotoxicity ' and LLM Output: 'Ketamine Side effects dizziness, neurotoxicity, cognitive dysfunction, blurred vision, psychosis, dissociation, urological dysfunction, restlessness, headache, nausea, vomiting, and cardiovascular symptoms' resulted in score: 0.2
# Evaluation for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Escitalopram Comparable to Sertraline in terms of efficacy and acceptability for the treatment of major depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Sertraline and Escitalopram Highly effective Acute treatment of major depression' resulted in score: 0.5
# Failed to extract score from evaluation: 1. Factual correctness: The LLM output is incorrect in terms of factual correctness. Nefazodone is being compared to SSRI in the ground truth, whereas the LLM output is comparing sertraline to escitalopram which are both SSRIs. Therefore, the facts in the LLM output are not correct compared to the ground truth.
#
# 2. Omissions: The LLM output does not miss any key details present in the ground truth since it focuses on comparing two specific SSRIs, sertraline and escitalopram, similar to the ground truth.
#
# 3. Contradictions: The LLM output does not directly contradict any information in the ground truth; however, the comparison made in the LLM
# Score extraction failed for Ground Truth: 'Nefazodone Is comparable to  SSRI' and LLM Output: 'Sertraline Comparable to escitalopram'
# Full Evaluation: 1. Factual correctness: The LLM output is incorrect in terms of factual correctness. Nefazodone is being compared to SSRI in the ground truth, whereas the LLM output is comparing sertraline to escitalopram which are both SSRIs. Therefore, the facts in the LLM output are not correct compared to the ground truth.
#
# 2. Omissions: The LLM output does not miss any key details present in the ground truth since it focuses on comparing two specific SSRIs, sertraline and escitalopram, similar to the ground truth.
#
# 3. Contradictions: The LLM output does not directly contradict any information in the ground truth; however, the comparison made in the LLM
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Escitalopram Comparable to Sertraline in terms of efficacy and acceptability for the treatment of major depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Escitalopram and Sertraline More favorable Profile of acceptability leading to significantly fewer discontinuations than Duloxetine, Fluvoxamine, Paroxetine, Reboxetine, and Venlafaxine' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Anxious depression Less commonly used adequate dose of citalopram due to side effects or patient’s choice' resulted in score: 0.0
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Escitalopram Comparable to Sertraline in terms of efficacy and acceptability for the treatment of major depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Nefazodone Side effects Rare cases of clinical idiosyncratic hepatotoxicity ' and LLM Output: 'Ketamine Side effects dizziness, neurotoxicity, cognitive dysfunction, blurred vision, psychosis, dissociation, urological dysfunction, restlessness, headache, nausea, vomiting, and cardiovascular symptoms' resulted in score: 0.3
# Evaluation for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Selective Serotonin Reuptake Inhibitors (SSRIs) first-line treatment Depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Bupropion Properties  Norepinephrine and dopamine reuptake inhibitor' and LLM Output: 'Ketamine Properties very quick effects on resistant unipolar depression and acute suicidal ideation' resulted in score: 0.5Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Sertraline and Escitalopram Highly effective Acute treatment of major depression' resulted in score: 0.9
#
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Escitalopram Comparable to Sertraline in terms of efficacy and acceptability for the treatment of major depression' resulted in score: 0.25
# Evaluation for Ground Truth: 'Nefazodone Is comparable to  SSRI' and LLM Output: 'Sertraline Comparable to Escitalopram' resulted in score: 0.0
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Selective Serotonin Reuptake Inhibitors (SSRIs) first-line treatment Depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Sertraline first-line treatment Moderate to severe major depression in adults' resulted in score: 0.5
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Depression Associated with poor quality of life and impaired functioning' resulted in score: 0.5
# Evaluation for Ground Truth: 'Nefazodone Side effects Rare cases of clinical idiosyncratic hepatotoxicity ' and LLM Output: 'SSRIs Side effects sexual dysfunction, loss of appetite, vomiting, nausea, irritability, anxiety, insomnia, and headache' resulted in score: 0.5
# Evaluation for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Escitalopram and Sertraline Properties Show the best profile of acceptability, leading to significantly fewer discontinuations than do duloxetine, fluvoxamine, paroxetine, reboxetine, and venlafaxine' resulted in score: 0.5
# Evaluation for Ground Truth: 'Bupropion Properties  Norepinephrine and dopamine reuptake inhibitor' and LLM Output: 'Selective Serotonin Reuptake Inhibitor antidepressants first-line treatment Major Depressive Disorder during the acute phase' resulted in score: 0.0
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Mirtazapine, Escitalopram, Venlafaxine, and Sertraline More effective than Duloxetine, Fluoxetine, Fluvoxamine, Paroxetine, and Reboxetine for treating Major Depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Bupropion Properties Has a more activating profile than SSRIs that are modestly superior to bupropion in patients with MDD' and LLM Output: 'Major Depressive Disorder Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning' resulted in score: 0.5Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Escitalopram Comparable to Sertraline in terms of efficacy and acceptability for the treatment of major depression' resulted in score: 0.5
#
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Depression-focused psychotherapy second-line treatment Depression' resulted in score: 0.5
# Evaluation for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Sertraline Comparable to Escitalopram in terms of balance between benefits, acceptability, and acquisition cost for treating Major Depression' resulted in score: 0.2
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'New-generation antidepressants Associated with Inconsistency in results regarding efficacy' resulted in score: 0.5
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Major Depression Definition a mental health disorder characterized by a pervasive and persistent low mood, accompanied by low self-esteem and loss of interest or pleasure in normally enjoyable activities' resulted in score: 0.5
# ...
# Best Evaluation: 1. Factual correctness: The LLM output is mostly correct in terms of factual accuracy when compared to the ground truth. It correctly mentions the inconsistency in results regarding the efficacy of new-generation antidepressants.
#
# 2. Omissions: The LLM output misses the key detail that repetitive Transcranial Magnetic Stimulation (rTMS) is more effective than antidepressants in the ground truth statement. This omission is significant as it alters the overall message conveyed.
#
# 3. Contradictions: There are no direct contradictions in the LLM output compared to the ground truth statement.
#
# Overall correctness score: 0.7
#
# Explanation: While the LLM output accurately highlights the inconsistency in results regarding the efficacy of new-generation antidepressants, it fails to include the
# ----------------------
# Ground Truth: Mindfulness-based cognitive therapy Goal Reduce, or even stop, antidepressant treatment without increasing the risk of depressive recurrence, especially for patients at a high risk of relapse
# Best LLM Output: Mindfulness-Based Cognitive Therapy (MBCT) Potential alternative  to reduce or even stop antidepressant treatment without increasing the risk of depressive recurrence
# Best Evaluation: Overall correctness score: 0.75
#
# Explanation: The LLM output accurately captures the main goal of mindfulness-based cognitive therapy in reducing or stopping antidepressant treatment without increasing the risk of depressive recurrence. However, it omits the specific mention of patients at high risk of relapse, which is a key detail present in the ground truth. There are no contradictions between the LLM output and the ground truth.
# ----------------------
# Ground Truth: Transcranial direct current stimulation Results Outperforms the simulator by rate of response and remission
# Best LLM Output: Major Depressive Disorder Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning
# Best Evaluation: Overall correctness score: 0.5
#
# 1. Factual correctness: The LLM output is not factually correct as it is completely unrelated to the ground truth statement about transcranial direct current stimulation. Score: 0
# 2. Omissions: The LLM output does not miss any key details present in the ground truth since they are completely different topics. Score: 1
# 3. Contradictions: The LLM output does not contradict any information in the ground truth since they are unrelated. Score: 1
#
# Explanation: The LLM output is factually incorrect as it discusses Major Depressive Disorder, which is unrelated to the topic of transcranial direct current stimulation. However, since there are no contradictions and omissions
# ----------------------
# Ground Truth: Transcranial direct current stimulation Findings Well-suited for remote supervised treatment and assessment at home
# Best LLM Output: Acute treatment duration for Major Depression Definition 8-week treatment period
# Best Evaluation: Overall correctness score: 0.5
#
# Explanation:
# 1. Factual correctness: The LLM output is not factually correct compared to the ground truth. The LLM output talks about the duration of treatment for Major Depression, which is not relevant to the topic of Transcranial direct current stimulation.
# 2. Omissions: The LLM output misses key details present in the ground truth. It does not mention anything about Transcranial direct current stimulation being well-suited for remote supervised treatment and assessment at home.
# 3. Contradictions: The LLM output contradicts the information in the ground truth by discussing a different treatment and duration period for a different condition.
#
# Overall, the LLM output is not correct in terms
# ----------------------
# Ground Truth: Psycho-education Goal Addresses Issues such as misperceptions about medication, treatment duration, the risk of relapse, and prodromes of depression
# Best LLM Output: Phototherapy Effective for both seasonal and non-seasonal depression
# Best Evaluation: 1. Factual correctness: 0 - The LLM output does not directly address any of the issues mentioned in the ground truth related to medication, treatment duration, risk of relapse, and prodromes of depression. Instead, it focuses on the effectiveness of phototherapy for depression.
# 2. Omissions: 1 - The LLM output does not miss any key details present in the ground truth as it simply talks about the effectiveness of phototherapy for both seasonal and non-seasonal depression.
# 3. Contradictions: 1 - The LLM output does not contradict any information in the ground truth as it does not make any claims that directly go against the facts presented.
#
# Overall correctness score: 0.6
# Explanation: While the
# ----------------------
# Ground Truth: Fluoxetine Moderate efficacy for Anxiety
# Best LLM Output: Escitalopram and Sertraline Overview Good balance between benefits, acceptability, and acquisition cost for moderate to severe major depression
# Best Evaluation: Overall Correctness Score: 0.5
#
# Explanation:
# 1. Factual correctness: The LLM output discusses Escitalopram and Sertraline for major depression, which is not directly related to the ground truth statement about Fluoxetine for anxiety. This leads to a lack of factual correctness in the output.
# 2. Omissions: The LLM output does not mention Fluoxetine or anxiety, which are key details present in the ground truth. This is a significant omission.
# 3. Contradictions: The LLM output does not directly contradict any information in the ground truth, but it does not align with it either.
#
# Overall, the LLM output lacks factual correctness and important details compared to the ground truth, resulting in a
# ----------------------
# Ground Truth: Magnetic Seizure Therapy Entials Inducing a therapeutic seizure by applying magnetic stimulation to the brain while the patient is under anesthesia
# Best LLM Output: Major Depressive Disorder Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning
# Best Evaluation: Overall Correctness Score: 0.5
#
# Explanation:
# 1. Factual correctness: The LLM output is not factually correct as it talks about Major Depressive Disorder, which is unrelated to Magnetic Seizure Therapy. Score: 0
# 2. Omissions: The LLM output completely misses the key details present in the ground truth about Magnetic Seizure Therapy. Score: 0
# 3. Contradictions: The LLM output contradicts the information in the ground truth by discussing a different topic altogether. Score: 1
#
# Due to the complete lack of relevance and factual accuracy in the LLM output, the overall correctness score is 0.5.
# ----------------------
# Ground Truth: Electroconvulsive therapy Eligible for Patients with severe and psychotic depression, a high risk of suicide, or Parkinson’s disease, as well as pregnant patients
# Best LLM Output: Major Depressive Disorder Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning
# Best Evaluation: Overall Correctness Score: 0.5
#
# Explanation:
# 1. Factual correctness: The LLM output is not factually correct as it discusses Major Depressive Disorder rather than Electroconvulsive therapy and its specific eligibility criteria mentioned in the ground truth.
# 2. Omissions: The LLM output misses key details present in the ground truth such as the specific conditions for which Electroconvulsive therapy is eligible.
# 3. Contradictions: There is a contradiction between the information in the LLM output and the ground truth as they discuss different topics related to mental health.
#
# Overall, the LLM output lacks factual correctness, misses key details, and contradicts the information provided in the ground truth.
# ----------------------
# Ground Truth: Electroconvulsive therapy Effective Acute phase of depression in some situations
# Best LLM Output: Electroconvulsive therapy (ECT) Highly effective somatic therapy for depression in some specific situations
# Best Evaluation: Overall correctness score: 0.8
#
# Explanation:
# 1. Factual correctness: The LLM output correctly states that Electroconvulsive therapy (ECT) is effective for depression in some situations, aligning with the ground truth. However, the use of the term "Highly effective somatic therapy" may be slightly overstated compared to the more general "Effective" in the ground truth. (Score: 0.9)
#
# 2. Omissions: The LLM output does not miss any key details present in the ground truth. It provides a slightly more detailed description by including "Highly effective" and "somatic therapy," but this does not change the overall meaning. (Score: 1.0)
#
# 3. Contradictions
# ----------------------
# Ground Truth: Fluoxetine Side effects Generally acceptable side effect profile
# Best LLM Output: SSRIs Side effects sexual dysfunction, loss of appetite, vomiting, nausea, irritability, anxiety, insomnia, and headache
# Best Evaluation: Overall correctness score: 0.5
#
# Explanation: The LLM output correctly identifies some side effects of fluoxetine (sexual dysfunction, loss of appetite, vomiting, nausea, irritability, anxiety, insomnia, and headache) which align with the general side effects of SSRIs. However, it misses the key detail that the overall side effect profile of fluoxetine is generally acceptable according to the ground truth. There is no direct contradiction between the LLM output and the ground truth, but the omission of the acceptability of side effects impacts the overall correctness of the output.
# ----------------------
# Ground Truth: Fluvoxamine Side effects Lower acceptability due to reduced efficacy
# Best LLM Output: SSRIs Side effects sexual dysfunction, loss of appetite, vomiting, nausea, irritability, anxiety, insomnia, and headache
# Best Evaluation: 1. Factual correctness: The LLM output mentions several side effects of SSRIs, which are generally accurate. However, it does not specifically mention fluvoxamine or reduced efficacy as stated in the ground truth. Score: 0.7
#
# 2. Omissions: The LLM output misses the key detail of fluvoxamine specifically and the reduced efficacy aspect mentioned in the ground truth. Score: 0.5
#
# 3. Contradictions: The LLM output does not directly contradict any information in the ground truth. Score: 1.0
#
# Overall correctness score: (0.7 + 0.5 + 1.0) / 3 = 0.73
#
# Explanation: The LLM output provides general
# ----------------------
# Ground Truth: Transcranial direct current stimulation Results Lower than that of antidepressants and rTMS
# Best LLM Output: Transcranial Direct Current Stimulation (tDCS) less effective than antidepressants and Repetitive Transcranial Magnetic Stimulation (rTMS) for the acute treatment of major depression
# Best Evaluation: Overall Correctness Score: 0.8
#
# Explanation:
# 1. Factual correctness: The facts in the LLM output are mostly correct compared to the ground truth. It correctly states that tDCS is less effective than antidepressants and rTMS for major depression treatment.
# 2. Omissions: The LLM output does not miss any key details present in the ground truth. It includes all relevant information.
# 3. Contradictions: There are no contradictions between the information in the LLM output and the ground truth. The statements align in terms of effectiveness comparison.
#
# Overall, the LLM output has captured the essence of the ground truth statement accurately, with minor differences in wording.
# ----------------------
# Ground Truth: Luxtherapy Eligible for Those with seasonal and non-seasonal depression. Benefits to sleep deprivation and drug treatments have also been reported
# Best LLM Output: Phototherapy Effective for both seasonal and non-seasonal depression
# Best Evaluation: Overall Correctness Score: 0.75
#
# Explanation: The LLM output accurately captures the essence of the ground truth by stating that phototherapy is effective for both seasonal and non-seasonal depression. However, it does omit some key details such as the eligibility criteria for Luxtherapy and the additional benefits to sleep deprivation and drug treatments. There are no contradictions between the LLM output and the ground truth.
# ----------------------
# Ground Truth: Duloxetine Side effects Lower acceptability
# Best LLM Output: Escitalopram and Sertraline Side effects significantly fewer discontinuations
# Best Evaluation: Overall correctness score: 0.75
#
# 1. Factual correctness: The LLM output correctly mentions that Escitalopram and Sertraline have significantly fewer discontinuations, which aligns with the idea of lower acceptability of side effects in the ground truth. Score: 1
#
# 2. Omissions: The LLM output misses explicitly mentioning Duloxetine, which is the specific drug mentioned in the ground truth. This omission could potentially lead to confusion or lack of clarity. Score: 0.5
#
# 3. Contradictions: The LLM output does not directly contradict the ground truth. However, it focuses on a different angle by discussing fewer discontinuations rather than directly addressing lower acceptability of side effects. Score:
# ----------------------
# Ground Truth: Deep Brain Stimulation Findings Elicited a clinical response in 60% of resistant depression patients after six months and clinical remission in 35% of patients, with benefits maintained for over 12 mo
# Best LLM Output: Electroconvulsive therapy (ECT) Highly effective somatic therapy for depression in some specific situations
# Best Evaluation: Overall Correctness Score: 0.5
#
# Explanation: The LLM output correctly mentions that electroconvulsive therapy (ECT) is a highly effective somatic therapy for depression in some specific situations, which aligns with the idea of treatment for depression. However, the LLM output fails to accurately represent the specific findings related to Deep Brain Stimulation for resistant depression patients as stated in the ground truth. Additionally, the LLM output lacks key details such as the percentage of patients experiencing a clinical response and remission after six months and over 12 months. Therefore, while the general idea of treating depression is highlighted in the LLM output, it falls short in providing precise and detailed information compared to the ground truth.
# ----------------------
#                                         ground_truth  \
# 0  Pharmacotherapy Entails Monoamine oxidase inhi...
# 1                   Depression Side effect Mortality
# 2  Pharmacotherapy Entails Norepinephrine reuptak...
# 3                       SSRIs  Same efficacy as TCAs
# 4  Monoamine oxidase inhibitors Same efficacy as ...
# 5           Depression Side effect Suicidal behavior
# 6  Trazodone Use In low doses as a sedative hypnotic
# 7  Monoamine oxidase inhibitors Eligible for  Pat...
# 8                 SSRIs Is a part of Pharmacotherapy
# 9  Monoamine oxidase inhibitors Side effects Hepa...
#
#                                      best_llm_output  \
# 0  Monoamine Oxidase Inhibitors (MAOIs) less comm...
# 1  All Depression Associated with high rates of s...
# 2  Selective Serotonin Reuptake Inhibitors (SSRIs...
# 3        Mirtazapine Comparable to SSRIs in efficacy
# 4  Monoamine Oxidase Inhibitors Less commonly use...
# 5  Ketamine Properties very quick effects on resi...
# 6  Anxious depression side effects high mean QIDS...
# 7  Monoamine Oxidase Inhibitors (MAOIs) Less comm...
# 8  Major Depressive Disorder Definition a prevale...
# 9  Monoamine Oxidase Inhibitors (MAOIs) Less comm...
#
#                                      best_evaluation
# 0  Overall correctness score: 0.75\n\n1. Factual ...
# 1  Overall correctness score: 0.75\n\n1. Factual ...
# 2  Overall Correctness Score: 0.5\n\nExplanation:...
# 3  Overall correctness score: 0.5\n\nExplanation:...
# 4  Overall Correctness Score: 0.5\n\nExplanation:...
# 5  1. Factual correctness: The LLM output correct...
# 6  Overall Correctness Score: 0.5\n\nExplanation:...
# 7  Overall Correctness Score: 0.75\n\nExplanation...
# 8  Overall correctness score: 0.5\n\nExplanation:...
# 9  Overall correctness score: 0.8\n\n1. Factual c...

# %% [markdown]
# ## RAGA evaluation

# %% [markdown]
# ### Optimized GPT Critic parallel batch

# %%
import concurrent.futures
import re
import openai
import pandas as pd

openai.api_key = ''

llm_output = pd.read_csv("Temperature1_WithoutExamples_cleaned.csv")
ground_truth = pd.read_csv("Annotations.csv")

def extract_raga_scores(evaluation):
    """
    Extract scores for RAGA components: Retrieval, Augmentation, Generation, Attribution.
    """
    retrieval = re.search(r'Retrieval:\s*([0-1](?:\.\d+)?)', evaluation)
    augmentation = re.search(r'Augmentation:\s*([0-1](?:\.\d+)?)', evaluation)
    generation = re.search(r'Generation:\s*([0-1](?:\.\d+)?)', evaluation)
    attribution = re.search(r'Attribution:\s*([0-1](?:\.\d+)?)', evaluation)

    if retrieval and augmentation and generation and attribution:
        return {
            'retrieval': float(retrieval.group(1)),
            'augmentation': float(augmentation.group(1)),
            'generation': float(generation.group(1)),
            'attribution': float(attribution.group(1))
        }
    return None

def is_relevant(ground_truth, llm_output):
    gt_terms = set(ground_truth.lower().split())
    llm_terms = set(llm_output.lower().split())
    relevance = gt_terms.intersection(llm_terms)
    return len(relevance) > 1

def create_raga_prompt(ground_truth_row, llm_output_row):
    prompt = f"""
    I want you to compare the following statements.

    Ground Truth: {ground_truth_row}
    
    LLM Output: {llm_output_row}
    
    Based on the ground truth, evaluate the correctness of the LLM output in terms of:
    1. **Retrieval**: How well the LLM output retrieves information relevant to the ground truth.
    2. **Augmentation**: How well the LLM output synthesizes the retrieved information to form a coherent response.
    3. **Generation**: Is the LLM output fluent and grammatically correct?
    4. **Attribution**: Can the LLM output be directly attributed to the ground truth, without unsupported claims?

    You are required to provide a score from 0 to 1 for each component (1 being the best), and include a short explanation of the result.
    """
    return prompt

def get_critic_gpt_evaluation(prompt):
    try:
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[{"role": "user", "content": prompt}],
            max_tokens=200
        )
        return response['choices'][0]['message']['content'].strip()
    except Exception as e:
        print(f"Error during evaluation: {e}")
        return None

def evaluate_row_raga(gt_row, llm_output):
    best_evaluation = None
    best_llm_row = None
    best_scores = {
        'retrieval': -1,
        'augmentation': -1,
        'generation': -1,
        'attribution': -1
    }

    for j in range(len(llm_output)):
        llm_subj = llm_output.loc[j, 'subj']
        llm_rel = llm_output.loc[j, 'rel']
        llm_obj = llm_output.loc[j, 'obj']
        llm_row = f"{llm_subj} {llm_rel} {llm_obj}"
        
        if not is_relevant(gt_row, llm_row):
            continue

        prompt = create_raga_prompt(gt_row, llm_row)
        evaluation = get_critic_gpt_evaluation(prompt)

        if evaluation:
            raga_scores = extract_raga_scores(evaluation)
            if raga_scores:
                print(f"Evaluation for Ground Truth: '{gt_row}' and LLM Output: '{llm_row}' resulted in RAGA scores: {raga_scores}")

                # Check if this evaluation has better RAGA scores
                if sum(raga_scores.values()) > sum(best_scores.values()):
                    best_scores = raga_scores
                    best_evaluation = evaluation
                    best_llm_row = llm_row

    if best_llm_row and best_evaluation:
        return {
            'ground_truth': gt_row,
            'best_llm_output': best_llm_row,
            'best_evaluation': best_evaluation,
            **best_scores
        }
    return None

# Parallel processing of ground truth rows using RAGA
best_matches = []
ground_truth_rows = []

for i in range(len(ground_truth)):
    gt_subj = ground_truth.loc[i, 'subj']
    gt_rel = ground_truth.loc[i, 'rel']
    gt_obj = ground_truth.loc[i, 'obj']
    gt_row = f"{gt_subj} {gt_rel} {gt_obj}"
    ground_truth_rows.append(gt_row)

with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    future_to_row = {executor.submit(evaluate_row_raga, gt_row, llm_output): gt_row for gt_row in ground_truth_rows}

    for future in concurrent.futures.as_completed(future_to_row):
        try:
            result = future.result()
            if result:
                best_matches.append(result)
        except Exception as e:
            print(f"Error processing a row: {e}")

# Print RAGA results
print('----------------------')
for match in best_matches:
    print(f"Ground Truth: {match['ground_truth']}")
    print(f"Best LLM Output: {match['best_llm_output']}")
    print(f"Best Evaluation: {match['best_evaluation']}")
    print(f"Retrieval Score: {match['retrieval']}, Augmentation Score: {match['augmentation']}, Generation Score: {match['generation']}, Attribution Score: {match['attribution']}")
    print('----------------------')

# Save results to DataFrame and optionally CSV
results_df = pd.DataFrame(best_matches)
print(results_df.head(10))
# results_df.to_csv('comparison_raga_results.csv', index=False)
# Out:
# Evaluation for Ground Truth: 'Depression Side effect Suicidal behavior' and LLM Output: 'Ketamine Properties very quick effects on resistant unipolar depression and acute suicidal ideation' resulted in RAGA scores: {'retrieval': 0.75, 'augmentation': 0.8, 'generation': 0.9, 'attribution': 0.7}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Same efficacy as Tricyclic antidepressants' and LLM Output: 'Monoamine Oxidase Inhibitors Less commonly used Major Depressive Disorder' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.7, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Monoamine Oxidase Inhibitors Less commonly used Major Depressive Disorder' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.2, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'All Depression Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 1.0, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Pharmacotherapy Entails Norepinephrine reuptake inhibitors' and LLM Output: 'Selective Serotonin Reuptake Inhibitors (SSRIs) first-line treatment All Depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Major Depressive Disorder Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.0, 'generation': 0.5, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Electroconvulsive therapy Treats Depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.7, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Depression Side effect Mortality' and LLM Output: 'Anxious depression Side effects greater reduction in anxiety/somatization score yet greater residual symptoms of anxiety/somatization than nonanxious depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Escitalopram and Sertraline Overview Good balance between benefits, acceptability, and acquisition cost for moderate to severe major depression' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.6, 'generation': 0.8, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Same efficacy as Tricyclic antidepressants' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) Less commonly used due to side effects such as hepatotoxicity and hypertensive crisis' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.7, 'attribution': 0.4}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Combination of medication, psychotherapy, and somatic therapy Treats resistant form of depression' resulted in RAGA scores: {'retrieval': 0.7, 'augmentation': 0.5, 'generation': 0.8, 'attribution': 0.6}
# Evaluation for Ground Truth: 'Depression Side effect Mortality' and LLM Output: 'Anxious depression side effects high mean QIDS-SR score at exit, low raw QID-SR change score, low percentage change in QIDS-SR score than nonanxious depression' resulted in RAGA scores: {'retrieval': 0.75, 'augmentation': 0.8, 'generation': 0.9, 'attribution': 0.85}
# Evaluation for Ground Truth: 'Depression Side effect Suicidal behavior' and LLM Output: 'Major Depressive Disorder Symptom high rates of suicidal behavior and mortality' resulted in RAGA scores: {'retrieval': 0.8, 'augmentation': 0.7, 'generation': 0.9, 'attribution': 0.8}
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Depression-focused psychotherapy second-line treatment All Depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) Less commonly used due to side effects such as hepatotoxicity and hypertensive crisis' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.4}
# Evaluation for Ground Truth: 'Pharmacotherapy Entails Monoamine oxidase inhibitors' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) less commonly used antidepressants' resulted in RAGA scores: {'retrieval': 0.8, 'augmentation': 0.7, 'generation': 0.9, 'attribution': 0.8}
# Evaluation for Ground Truth: 'Depression Side effect Mortality' and LLM Output: 'Anxious depression Less commonly used adequate dose of citalopram due to side effects or patient’s choice' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.4, 'generation': 0.9, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Vagus Nerve Stimulation Treats resistant unilateral or bipolar depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.8, 'generation': 0.9, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Cognitive Behavioral Therapy and Interpersonal Therapy first-line treatment Mild to moderate Major Depressive Disorder' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.9, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Pharmacotherapy Entails Norepinephrine reuptake inhibitors' and LLM Output: 'Selective Serotonin Reuptake Inhibitors (SSRIs) first-line treatment Major Depressive Disorder during the acute phase' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.75, 'generation': 0.8, 'attribution': 0.25}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Reboxetine less effective All other tested antidepressants for Unipolar Major Depression in adults' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.2}
# Evaluation for Ground Truth: 'SSRIs Is a part of Pharmacotherapy' and LLM Output: 'Major Depressive Disorder Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.6, 'generation': 0.8, 'attribution': 0.4}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'All Depression Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning' resulted in RAGA scores: {'retrieval': 0.3, 'augmentation': 0.2, 'generation': 0.5, 'attribution': 0.1}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Physical exercise Associated with improvement in depression symptom and prevention of relapses' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.5, 'generation': 1.0, 'attribution': 0.5}
# Evaluation for Ground Truth: 'Pharmacotherapy Entails Norepinephrine reuptake inhibitors' and LLM Output: 'Selective Serotonin Reuptake Inhibitors (SSRIs) first-line treatment All Depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Escitalopram Comparable to Sertraline in terms of efficacy and acceptability for the treatment of major depression' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.1}
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Escitalopram and Sertraline Overview Good balance between benefits, acceptability, and acquisition cost for moderate to severe major depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.8, 'generation': 0.9, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'SSRIs Side effects sexual dysfunction, loss of appetite, vomiting, nausea, irritability, anxiety, insomnia, and headache' resulted in RAGA scores: {'retrieval': 0.25, 'augmentation': 0.5, 'generation': 1.0, 'attribution': 0.0}
# Evaluation for Ground Truth: 'SSRIs Is a part of Pharmacotherapy' and LLM Output: 'All Depression Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.5, 'generation': 0.8, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Depression Side effect Suicidal behavior' and LLM Output: 'Anxious depression Less commonly used adequate dose of citalopram due to side effects or patient’s choice' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'All Depression Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.7, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Mirtazapine Comparable to SSRIs in efficacy' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.5, 'generation': 1.0, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Escitalopram and Sertraline first-line treatment Moderate to severe major depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Physical exercise Associated with improvement in depression symptom and prevention of relapses' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.5, 'generation': 1.0, 'attribution': 0.0}
# Evaluation for Ground Truth: 'SSRIs Is a part of Pharmacotherapy' and LLM Output: 'Major Depressive Disorder Definition a prevalent psychiatric disorder leading to poor quality of life and impaired functioning' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.4, 'generation': 0.9, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Escitalopram and Sertraline Properties Show the best profile of acceptability, leading to significantly fewer discontinuations than do duloxetine, fluvoxamine, paroxetine, reboxetine, and venlafaxine' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.8, 'generation': 0.9, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Ketamine Properties very quick effects on resistant unipolar depression and acute suicidal ideation' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'All Depression Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Major Depressive Disorder Definition a prevalent psychiatric disorder leading to poor quality of life and impaired functioning' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.1}
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Escitalopram and Sertraline Better acceptability Duloxetine, Fluvoxamine, Paroxetine, Reboxetine, Venlafaxine' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.7, 'attribution': 0.6}
# Evaluation for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Mirtazapine Comparable to SSRIs in efficacy' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.2, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'All Depression Associated with high rates of suicidal behavior and mortality' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.5, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) Less commonly used due to side effects such as hepatotoxicity and hypertensive crisis' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Sertraline Comparable to Escitalopram in terms of balance between benefits, acceptability, and acquisition cost for treating Major Depression' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.5, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Ketamine Properties very quick effects on resistant unipolar depression and acute suicidal ideation' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.6, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Electroconvulsive therapy Definition the most effective somatic therapy for depression in specific situations' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.0, 'generation': 1.0, 'attribution': 0.0}
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Escitalopram and Sertraline Overview Good balance between benefits, acceptability, and acquisition cost for moderate to severe major depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 1.0, 'attribution': 0.7}
# Evaluation for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Escitalopram and Sertraline Overview Good balance between benefits, acceptability, and acquisition cost for moderate to severe major depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Physical exercise Treats All Depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.2, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Cognitive-Behavioral Therapy (CBT) first-line treatment Mild to Moderate Major Depressive Disorder' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.8, 'generation': 0.9, 'attribution': 0.6}Evaluation for Ground Truth: 'Trazodone Use In low doses as a sedative hypnotic' and LLM Output: 'Major Depression Definition a mental health disorder characterized by a pervasive and persistent low mood, accompanied by low self-esteem and loss of interest or pleasure in normally enjoyable activities' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.0, 'generation': 1.0, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) less commonly used antidepressants' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.5}
#
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'All Depression Associated with high rates of suicidal behavior and mortality' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.1}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Cognitive Behavioral Therapy and Interpersonal Therapy first-line treatment Mild to moderate Major Depressive Disorder' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.3, 'generation': 0.7, 'attribution': 0.1}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Selective Serotonin Reuptake Inhibitor antidepressants first-line treatment Major Depressive Disorder during the acute phase' resulted in RAGA scores: {'retrieval': 0.8, 'augmentation': 0.7, 'generation': 0.9, 'attribution': 0.8}
# Evaluation for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Selective Serotonin Reuptake Inhibitors (SSRIs) first-line treatment Major Depressive Disorder' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.7, 'attribution': 0.4}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Eligible for  Patients who do not respond to other treatments' and LLM Output: 'Interpersonal therapy (IPT) Comparable to CBT for mild to moderate major depressive episodes in adults' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.0}
# Evaluation for Ground Truth: 'SSRIs Is a part of Pharmacotherapy' and LLM Output: 'Major Depressive Disorder Definition a prevalent psychiatric disorder leading to poor quality of life and impaired functioning' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.8, 'generation': 0.9, 'attribution': 0.3}
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Selective Serotonin Reuptake Inhibitor antidepressants first-line treatment Major Depressive Disorder during the acute phase' resulted in RAGA scores: {'retrieval': 0.8, 'augmentation': 0.7, 'generation': 0.9, 'attribution': 0.7}
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Interpersonal Therapy (IPT) first-line treatment Mild to Moderate Major Depressive Disorder' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.8, 'attribution': 0.4}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Resistant forms of depression Treats Combination of medication, psychotherapy, and somatic therapy' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.2}
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Escitalopram and Sertraline first-line treatment Moderate to severe major depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.8, 'generation': 0.8, 'attribution': 0.5}
# Evaluation for Ground Truth: 'Nefazodone Side effects Rare cases of clinical idiosyncratic hepatotoxicity ' and LLM Output: 'Ketamine Side effects dizziness, neurotoxicity, cognitive dysfunction, blurred vision, psychosis, dissociation, urological dysfunction, restlessness, headache, nausea, vomiting, and cardiovascular symptoms' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.3, 'generation': 0.6, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Sertraline first-line treatment Moderate to severe major depression in adults' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.4}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Escitalopram and Sertraline first-line treatment Moderate to severe major depression' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.3, 'generation': 0.7, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Compared antidepressants Treatment options Acute treatment of unipolar major depression' resulted in RAGA scores: {'retrieval': 0.8, 'augmentation': 0.7, 'generation': 0.9, 'attribution': 0.8}
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Mirtazapine, Escitalopram, Venlafaxine, Sertraline More effective Duloxetine, Fluoxetine, Fluvoxamine, Paroxetine, Reboxetine for Unipolar Major Depression in adults' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Tricyclic antidepressants (TCAs) More effective than SSRIs in hospitalized patients with severe Major Depressive Disorder symptoms' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Nefazodone Is comparable to  SSRI' and LLM Output: 'Escitalopram Comparable to Sertraline in terms of efficacy and acceptability for the treatment of major depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.75, 'generation': 1.0, 'attribution': 0.5}
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Sertraline and Escitalopram Highly effective Acute treatment of major depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.9, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Major Depressive Disorder Definition a prevalent psychiatric disorder leading to poor quality of life and impaired functioning' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.5, 'generation': 0.5, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Ketamine Treats resistant unipolar and possibly bipolar depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.9, 'attribution': 0.3}
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Escitalopram and Sertraline More favorable Profile of acceptability leading to significantly fewer discontinuations than Duloxetine, Fluvoxamine, Paroxetine, Reboxetine, and Venlafaxine' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.8, 'generation': 0.9, 'attribution': 0.5}
# Evaluation for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Escitalopram Comparable to Sertraline in terms of efficacy and acceptability for the treatment of major depression' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.5, 'generation': 1.0, 'attribution': 0.0}
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Compared antidepressants Treatment options Acute treatment of unipolar major depression' resulted in RAGA scores: {'retrieval': 0.8, 'augmentation': 0.7, 'generation': 0.9, 'attribution': 0.6}
# Evaluation for Ground Truth: 'Nefazodone Is comparable to  SSRI' and LLM Output: 'Sertraline Comparable to Escitalopram in terms of balance between benefits, acceptability, and acquisition cost for treating Major Depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.8, 'attribution': 0.5}
# Evaluation for Ground Truth: 'Nefazodone Side effects Rare cases of clinical idiosyncratic hepatotoxicity ' and LLM Output: 'SSRIs Side effects sexual dysfunction, loss of appetite, vomiting, nausea, irritability, anxiety, insomnia, and headache' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.5, 'generation': 0.8, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) Less commonly used due to side effects such as hepatotoxicity and hypertensive crisis' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.2, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Sertraline and Escitalopram Highly effective Acute treatment of major depression' resulted in RAGA scores: {'retrieval': 0.8, 'augmentation': 0.7, 'generation': 0.9, 'attribution': 0.6}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Duloxetine and Paroxetine Side effects less well tolerated than Escitalopram and Sertraline' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.4, 'generation': 0.8, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Nefazodone Is comparable to  SSRI' and LLM Output: 'Interpersonal therapy (IPT) Comparable to CBT for mild to moderate major depressive episodes in adults' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.5, 'generation': 0.8, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Exercise Recommended as adjunct to treat Major Depressive Disorder' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.0, 'generation': 1.0, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Nefazodone Side effects Rare cases of clinical idiosyncratic hepatotoxicity ' and LLM Output: 'Monoamine Oxidase Inhibitors (MAOIs) Less commonly used due to side effects such as hepatotoxicity and hypertensive crisis' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.7, 'attribution': 0.2}
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Sertraline and Escitalopram Highly effective Acute treatment of major depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.8, 'generation': 0.9, 'attribution': 0.7}
# Evaluation for Ground Truth: 'Bupropion Properties  Norepinephrine and dopamine reuptake inhibitor' and LLM Output: 'Selective Serotonin Reuptake Inhibitor antidepressants first-line treatment Major Depressive Disorder' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.0, 'generation': 1.0, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Escitalopram Comparable to Sertraline in terms of efficacy and acceptability for the treatment of major depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.8, 'generation': 0.9, 'attribution': 0.5}
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Selective Serotonin Reuptake Inhibitors (SSRIs) first-line treatment Depression' resulted in RAGA scores: {'retrieval': 0.7, 'augmentation': 0.5, 'generation': 0.8, 'attribution': 0.6}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Anxious depression Side effects greater reduction in anxiety/somatization score yet greater residual symptoms of anxiety/somatization than nonanxious depression' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.0, 'generation': 1.0, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Nefazodone Is comparable to  SSRI' and LLM Output: 'Sertraline Comparable to escitalopram' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.2}
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Escitalopram Comparable to Sertraline in terms of efficacy and acceptability for the treatment of major depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.8, 'generation': 0.9, 'attribution': 0.3}
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Escitalopram Comparable to Sertraline in terms of efficacy and acceptability for the treatment of major depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.8, 'attribution': 0.5}Evaluation for Ground Truth: 'Bupropion Properties  Norepinephrine and dopamine reuptake inhibitor' and LLM Output: 'Ketamine Properties very quick effects on resistant unipolar depression and acute suicidal ideation' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.5, 'generation': 0.75, 'attribution': 0.0}
#
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Escitalopram and Sertraline More favorable Profile of acceptability leading to significantly fewer discontinuations than Duloxetine, Fluvoxamine, Paroxetine, Reboxetine, and Venlafaxine' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.5, 'generation': 1.0, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Nefazodone Side effects Rare cases of clinical idiosyncratic hepatotoxicity ' and LLM Output: 'Ketamine side effects dizziness, neurotoxicity, cognitive dysfunction, blurred vision, psychosis, dissociation, urological dysfunction, restlessness, headache, nausea, vomiting, and cardiovascular symptoms' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.1, 'generation': 0.5, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Depression-focused psychotherapy second-line treatment Depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.7, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Depression Associated with poor quality of life and impaired functioning' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Anxious depression side effects high mean QIDS-SR score at exit, low raw QID-SR change score, low percentage change in QIDS-SR score than nonanxious depression' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.1, 'generation': 0.5, 'attribution': 0.1}
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Mirtazapine, Escitalopram, Venlafaxine, and Sertraline More effective than Duloxetine, Fluoxetine, Fluvoxamine, Paroxetine, and Reboxetine for treating Major Depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Nefazodone Side effects Rare cases of clinical idiosyncratic hepatotoxicity ' and LLM Output: 'SSRIs side effects sexual and digestive issues' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.6, 'generation': 0.8, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Nefazodone Is comparable to  SSRI' and LLM Output: 'Sertraline Comparable to Escitalopram' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.8, 'generation': 0.9, 'attribution': 0.6}
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Cognitive-Behavioral Therapy (CBT) first-line treatment Depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.6, 'generation': 0.8, 'attribution': 0.4}Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Major Depression Definition a mental health disorder characterized by a pervasive and persistent low mood, accompanied by low self-esteem and loss of interest or pleasure in normally enjoyable activities' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.6, 'generation': 0.8, 'attribution': 0.4}
#
# Evaluation for Ground Truth: 'Bupropion Properties  Norepinephrine and dopamine reuptake inhibitor' and LLM Output: 'Selective Serotonin Reuptake Inhibitor antidepressants first-line treatment Major Depressive Disorder during the acute phase' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.5, 'generation': 0.7, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Sertraline first-line treatment Moderate to severe major depression in adults' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Side effects Hepatotoxicity and hypertensive crises ' and LLM Output: 'Anxious depression Less commonly used adequate dose of citalopram due to side effects or patient’s choice' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.0, 'generation': 0.5, 'attribution': 0.0}
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Escitalopram and Sertraline Properties Show the best profile of acceptability, leading to significantly fewer discontinuations than do duloxetine, fluvoxamine, paroxetine, reboxetine, and venlafaxine' resulted in RAGA scores: {'retrieval': 0.7, 'augmentation': 0.8, 'generation': 0.9, 'attribution': 0.7}
# Evaluation for Ground Truth: 'Nefazodone Side effects Rare cases of clinical idiosyncratic hepatotoxicity ' and LLM Output: 'Ketamine side effects dizziness, neurotoxicity, cognitive dysfunction, blurred vision, psychosis, dissociation, urological dysfunction, restlessness, headache, nausea, vomiting, and cardiovascular symptoms' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.1, 'generation': 0.5, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Bupropion Properties Has a more activating profile than SSRIs that are modestly superior to bupropion in patients with MDD' and LLM Output: 'Major Depressive Disorder Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.7, 'attribution': 0.2}
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Major Depression Definition a mental health disorder characterized by a pervasive and persistent low mood, accompanied by low self-esteem and loss of interest or pleasure in normally enjoyable activities' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Sertraline Comparable to Escitalopram in terms of balance between benefits, acceptability, and acquisition cost for treating Major Depression' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Interpersonal Therapy (IPT) first-line treatment Depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Sertraline Comparable to Escitalopram in terms of balance between benefits, acceptability, and acquisition cost for treating Major Depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.8, 'generation': 0.9, 'attribution': 0.7}
# Evaluation for Ground Truth: 'Bupropion Properties  Norepinephrine and dopamine reuptake inhibitor' and LLM Output: 'Escitalopram and Sertraline Properties Show the best profile of acceptability, leading to significantly fewer discontinuations than do duloxetine, fluvoxamine, paroxetine, reboxetine, and venlafaxine' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'New-generation antidepressants Associated with Inconsistency in results regarding efficacy' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.5, 'generation': 1.0, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Bupropion Properties A better tolerability than SSRIs, with minimal weight gain' and LLM Output: 'Tricyclic antidepressants (TCAs) More effective than SSRIs in hospitalized patients with severe Major Depressive Disorder symptoms' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.2, 'generation': 0.9, 'attribution': 0.2}
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Sertraline Comparable to Escitalopram in terms of balance between benefits, acceptability, and acquisition cost for treating Major Depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.75, 'generation': 0.75, 'attribution': 0.5}
# Evaluation for Ground Truth: 'Bupropion Properties Has a more activating profile than SSRIs that are modestly superior to bupropion in patients with MDD' and LLM Output: 'SSRIs More commonly used Major Depressive Disorder' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Sertraline Comparable to Escitalopram in terms of balance between benefits, acceptability, and acquisition cost for treating Major Depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.8, 'generation': 0.9, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Acute treatment duration for Major Depression Definition 8-week treatment period' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Sertraline Comparable to Escitalopram in terms of balance between benefits, acceptability, and acquisition cost for treating Major Depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.75, 'generation': 0.8, 'attribution': 0.5}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Escitalopram Comparable to Sertraline in terms of efficacy and acceptability for the treatment of major depression' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.0, 'generation': 1.0, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Tricyclic antidepressants (TCAs) more effective than SSRIs in hospitalized patients' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Bupropion Properties Has a more activating profile than SSRIs that are modestly superior to bupropion in patients with MDD' and LLM Output: 'Physical exercise Associated with improvement in depression symptom and prevention of relapses' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.5, 'generation': 0.8, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Selective Serotonin Reuptake Inhibitors (SSRIs) first-line treatment Major Depressive Disorder during the acute phase' resulted in RAGA scores: {'retrieval': 0.7, 'augmentation': 0.8, 'generation': 0.9, 'attribution': 0.6}
# Evaluation for Ground Truth: 'SSRIs Treat Acute phase of depression' and LLM Output: 'Acute treatment duration for Major Depression Definition 8-week treatment period' resulted in RAGA scores: {'retrieval': 0.7, 'augmentation': 0.8, 'generation': 0.9, 'attribution': 0.6}
# Evaluation for Ground Truth: 'SSRI Includes fluoxetine, sertraline, paroxetine, fluvoxamine, citalopram, and escitalopram' and LLM Output: 'Mirtazapine, escitalopram, venlafaxine, sertraline More effective duloxetine, fluoxetine, fluvoxamine, paroxetine, reboxetine' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.4, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Nefazodone Side effects Rare cases of clinical idiosyncratic hepatotoxicity ' and LLM Output: 'Duloxetine and Paroxetine Side effects less well tolerated than Escitalopram and Sertraline' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.3, 'generation': 0.7, 'attribution': 0.1}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'MAOIs Specific efficacy in treating Depression with atypical features' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.6, 'generation': 0.8, 'attribution': 0.5}
# Evaluation for Ground Truth: 'Norepinephrine reuptake inhibitors Eligible for Patients who do not respond to SSRIs' and LLM Output: 'Interpersonal therapy (IPT) Comparable to CBT for mild to moderate major depressive episodes in adults' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.0, 'generation': 1.0, 'attribution': 0.0}Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Reboxetine Not effective First-line acute treatment for major depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.5, 'generation': 0.8, 'attribution': 0.3}
#
# Evaluation for Ground Truth: 'Bupropion Properties  Norepinephrine and dopamine reuptake inhibitor' and LLM Output: 'Bupropion Properties minimal weight gain or even weight loss' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.2, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Bupropion Finding Is more likely than SSRIs to improve symptoms of fatigue and sleepiness' and LLM Output: 'Major Depressive Disorder Definition a prevalent psychiatric disorder that often leads to poor quality of life and impaired functioning' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.1}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Major Depression Definition a mental health disorder characterized by a pervasive and persistent low mood, accompanied by low self-esteem and loss of interest or pleasure in normally enjoyable activities' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.7, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Bupropion Properties Has a more activating profile than SSRIs that are modestly superior to bupropion in patients with MDD' and LLM Output: 'Anxious Depression more common than nonanxious depression in African American group, Hispanics, Primary Care Patients, Unemployed, Married then Divorced/Widowed, Less Education, Public insurance, Lower-income' resulted in RAGA scores: {'retrieval': 0.2, 'augmentation': 0.1, 'generation': 0.3, 'attribution': 0.1}
# Evaluation for Ground Truth: 'Pharmacotherapy Treats Acute phase of depression' and LLM Output: 'Ketamine Treats treatment-resistant unipolar and bipolar depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.7, 'generation': 0.8, 'attribution': 0.5}
# Evaluation for Ground Truth: 'Depression Side effect Slower response to treatment' and LLM Output: 'Selective Serotonin Reuptake Inhibitors (SSRIs) first-line treatment All Depression' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.8, 'attribution': 0.3}
# Evaluation for Ground Truth: 'Mianserin Properties Antagonizes serotoninergic subtypes receptors, <5-HT2A> and <5-HT2C>' and LLM Output: 'Ketamine Properties very quick effects on resistant unipolar depression and acute suicidal ideation' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.5, 'generation': 0.5, 'attribution': 0.0}
# Evaluation for Ground Truth: 'Bupropion Finding Is more likely than SSRIs to improve symptoms of fatigue and sleepiness' and LLM Output: 'SSRIs More commonly used Major Depressive Disorder' resulted in RAGA scores: {'retrieval': 0.5, 'augmentation': 0.3, 'generation': 0.7, 'attribution': 0.2}
# Evaluation for Ground Truth: 'Monoamine oxidase inhibitors Demonstrated specific efficacy in treating Atypical features, such as reactive moods, reverse neuro-vegetative symptoms, and sensitivity to rejection' and LLM Output: 'Second-generation antidepressants Associated with inconsistencies in efficacy results' resulted in RAGA scores: {'retrieval': 0.0, 'augmentation': 0.5, 'generation': 0.75, 'attribution': 0.0}
# ...
# Retrieval Score: 0.9, Augmentation Score: 0.8, Generation Score: 0.9, Attribution Score: 1.0
# ----------------------
# Ground Truth: Fluoxetine Moderate efficacy for Anxiety
# Best LLM Output: Escitalopram Comparable to Sertraline in terms of efficacy and acceptability for the treatment of major depression
# Best Evaluation: 1. Retrieval: 0.5
# The LLM output does not directly retrieve information about Fluoxetine or Anxiety as mentioned in the ground truth. However, it does mention efficacy in the context of treatment, which is somewhat related.
#
# 2. Augmentation: 0.7
# The LLM output synthesizes the information about the efficacy and acceptability of different medications for depression, which is somewhat related to the treatment aspect mentioned in the ground truth. However, it does not directly address anxiety.
#
# 3. Generation: 0.9
# The LLM output is fluent and grammatically correct, forming a coherent response about the comparison of two medications for major depression treatment.
#
# 4. Attribution: 0.3
# The LLM output cannot be directly attributed to the ground truth as it discusses major depression treatment instead of anxiety and mentions different medications (Escitalopram and Sertraline) than Fluoxetine. The claims made are unsupported when compared to the ground truth statement.
# Retrieval Score: 0.5, Augmentation Score: 0.7, Generation Score: 0.9, Attribution Score: 0.3
# ----------------------
# Ground Truth: Transcranial direct current stimulation Findings Well-suited for remote supervised treatment and assessment at home
# Best LLM Output: Phototherapy Effective for both seasonal and non-seasonal depression
# Best Evaluation: 1. Retrieval: 0.5
# The LLM output does not directly retrieve information related to transcranial direct current stimulation, as it discusses phototherapy for depression instead. However, both treatments are related to mental health, which is why a partial score is given.
#
# 2. Augmentation: 0.8
# The LLM output synthesizes the information about phototherapy effectively, mentioning its effectiveness for both seasonal and non-seasonal depression. This augmentation is relevant and coherent in the context of mental health treatments.
#
# 3. Generation: 1
# The LLM output is fluent and grammatically correct, presenting the information clearly and concisely.
#
# 4. Attribution: 0.3
# The LLM output cannot be directly attributed to the ground truth since it discusses a different treatment modality. The mention of phototherapy for depression does not align with the original statement about transcranial direct current stimulation.
#
# Overall, the LLM output scores well in terms of generation and augmentation but
# Retrieval Score: 0.5, Augmentation Score: 0.8, Generation Score: 1.0, Attribution Score: 0.3
# ----------------------
# Ground Truth: Magnetic Seizure Therapy Entials Inducing a therapeutic seizure by applying magnetic stimulation to the brain while the patient is under anesthesia
# Best LLM Output: Electroconvulsive therapy Definition the most effective somatic therapy for depression in specific situations
# Best Evaluation: 1. Retrieval: 0.5
# The LLM output partially retrieves information relevant to the ground truth by mentioning electroconvulsive therapy, which is a form of seizure therapy. However, it does not specifically mention magnetic seizure therapy or the use of magnetic stimulation.
#
# 2. Augmentation: 0.7
# The LLM output synthesizes the retrieved information fairly well by stating that electroconvulsive therapy is effective for depression in specific situations, which can be considered a coherent response. However, it lacks the specific details related to inducing seizures and magnetic stimulation.
#
# 3. Generation: 0.8
# The LLM output is fluent and grammatically correct, making it easy to read and understand.
#
# 4. Attribution: 0.3
# The LLM output cannot be directly attributed to the ground truth as it focuses on electroconvulsive therapy rather than magnetic seizure therapy. It makes a claim about electroconvulsive therapy without directly relating it to the ground truth of magnetic seizure therapy.
# Retrieval Score: 0.5, Augmentation Score: 0.7, Generation Score: 0.8, Attribution Score: 0.3
# ----------------------
# Ground Truth: Transcranial direct current stimulation Results Lower than that of antidepressants and rTMS
# Best LLM Output: Escitalopram and Sertraline Properties Show the best profile of acceptability, leading to significantly fewer discontinuations than do duloxetine, fluvoxamine, paroxetine, reboxetine, and venlafaxine
# Best Evaluation: 1. Retrieval: 0.5
# The LLM output does not directly address the comparison between transcranial direct current stimulation and antidepressants/rTMS mentioned in the ground truth. However, it does discuss different antidepressants and their acceptability profiles, which is somewhat related to the topic.
#
# 2. Augmentation: 0.8
# The LLM output effectively synthesizes information about different antidepressants and their acceptability profiles, providing a coherent response. However, it does not directly address the comparison mentioned in the ground truth.
#
# 3. Generation: 0.9
# The LLM output is fluent and grammatically correct, with no obvious issues in terms of language or structure.
#
# 4. Attribution: 0.3
# While the LLM output provides relevant information about antidepressants and their acceptability profiles, it does not directly address the ground truth statement about transcranial direct current stimulation and its comparison to antidepressants/rTMS. Therefore, the attribution score is low.
# Retrieval Score: 0.5, Augmentation Score: 0.8, Generation Score: 0.9, Attribution Score: 0.3
# ----------------------
# Ground Truth: Electroconvulsive therapy Eligible for Patients with severe and psychotic depression, a high risk of suicide, or Parkinson’s disease, as well as pregnant patients
# Best LLM Output: Electroconvulsive therapy Definition the most effective somatic therapy for depression in specific situations
# Best Evaluation: Retrieval: 0.5
# The LLM output does not directly mention specific situations such as severe and psychotic depression, a high risk of suicide, Parkinson's disease, or pregnancy, which are key criteria mentioned in the ground truth. The information about the most effective somatic therapy for depression is related but not as specific as the ground truth.
#
# Augmentation: 0.7
# The LLM output synthesizes the information about electroconvulsive therapy being effective for depression in specific situations, which shows some level of coherence in the response. However, it lacks the specific details mentioned in the ground truth criteria.
#
# Generation: 0.9
# The LLM output is fluent and grammatically correct, presenting the information in a clear manner.
#
# Attribution: 0.6
# While the information in the LLM output is related to electroconvulsive therapy and depression, it does not directly mirror the criteria mentioned in the ground truth. It contains some unsupported claims by not including specific situations like
# Retrieval Score: 0.5, Augmentation Score: 0.7, Generation Score: 0.9, Attribution Score: 0.6
# ----------------------
# Ground Truth: Fluvoxamine Side effects Lower acceptability due to reduced efficacy
# Best LLM Output: Escitalopram and Sertraline More favorable Profile of acceptability leading to significantly fewer discontinuations than Duloxetine, Fluvoxamine, Paroxetine, Reboxetine, and Venlafaxine
# Best Evaluation: 1. Retrieval: 0.5
# The LLM output does mention Fluvoxamine, which is relevant to the ground truth. However, it also includes other drugs not mentioned in the ground truth statement, which might reduce the relevance.
#
# 2. Augmentation: 0.75
# The LLM output synthesizes the information about acceptability and discontinuations of different drugs, which is related to the ground truth statement. However, it includes more information than necessary, which might make the response less focused.
#
# 3. Generation: 0.8
# The LLM output is fluent and grammatically correct. It presents the information clearly and logically.
#
# 4. Attribution: 0.5
# While the LLM output does mention Fluvoxamine, which is in line with the ground truth, it also includes additional drugs not mentioned in the ground truth statement. This might lead to potential confusion and detract from directly attributing the response to the ground truth.
#
# Overall, the LLM output
# Retrieval Score: 0.5, Augmentation Score: 0.75, Generation Score: 0.8, Attribution Score: 0.5
# ----------------------
# Ground Truth: Fluoxetine Side effects Generally acceptable side effect profile
# Best LLM Output: SSRIs side effects sexual and digestive issues, irritability, anxiety, insomnia, and headaches
# Best Evaluation: 1. Retrieval: 0.5
# The LLM output partially retrieves information relevant to the ground truth, as it mentions some side effects associated with SSRIs, but it does not specifically mention Fluoxetine.
#
# 2. Augmentation: 0.6
# The LLM output synthesizes the retrieved information fairly well by listing various side effects of SSRIs, although it lacks specificity to Fluoxetine.
#
# 3. Generation: 0.8
# The LLM output is fluent and grammatically correct, with no obvious errors in language use.
#
# 4. Attribution: 0.4
# The LLM output cannot be directly attributed to the ground truth, as it focuses on SSRIs in general rather than specifically on Fluoxetine. It includes additional side effects not mentioned in the ground truth.
# Retrieval Score: 0.5, Augmentation Score: 0.6, Generation Score: 0.8, Attribution Score: 0.4
# ----------------------
# Ground Truth: Duloxetine Side effects Lower acceptability
# Best LLM Output: Escitalopram and Sertraline Side effects significantly fewer discontinuations
# Best Evaluation: 1. Retrieval: 0.75
# The LLM output successfully retrieves relevant information about side effects and discontinuations of different medications, which aligns with the ground truth statement about Duloxetine side effects. However, the key term "lower acceptability" from the ground truth is not directly mentioned in the LLM output.
#
# 2. Augmentation: 0.8
# The LLM output synthesizes the information about Escitalopram and Sertraline having fewer discontinuations to suggest that they may have lower acceptability. This augmentation is logical and coherent in response to the ground truth statement.
#
# 3. Generation: 0.9
# The LLM output is fluent and grammatically correct. The response is well-structured and easily understandable.
#
# 4. Attribution: 0.75
# While the LLM output provides relevant information related to side effects and discontinuations of medications, the direct link to the term "lower acceptability" in the ground truth statement is somewhat indirect. It
# Retrieval Score: 0.75, Augmentation Score: 0.8, Generation Score: 0.9, Attribution Score: 0.75
# ----------------------
# Ground Truth: Luxtherapy Eligible for Those with seasonal and non-seasonal depression. Benefits to sleep deprivation and drug treatments have also been reported
# Best LLM Output: Phototherapy Effective for both seasonal and non-seasonal depression
# Best Evaluation: 1. Retrieval: 0.75
# The LLM output effectively retrieves information relevant to the ground truth by mentioning that phototherapy is effective for both seasonal and non-seasonal depression, which aligns with the eligibility criteria mentioned in the ground truth.
#
# 2. Augmentation: 0.5
# The LLM output falls short in synthesizing the retrieved information to form a coherent response. While it mentions the effectiveness of phototherapy for both types of depression, it misses out on highlighting the benefits to sleep deprivation and drug treatments mentioned in the ground truth.
#
# 3. Generation: 0.75
# The LLM output is fluent and grammatically correct, presenting the information in a clear and concise manner.
#
# 4. Attribution: 0.75
# The LLM output can be directly attributed to the ground truth without making any unsupported claims. It stays within the boundaries of the information provided in the ground truth.
# Retrieval Score: 0.75, Augmentation Score: 0.5, Generation Score: 0.75, Attribution Score: 0.75
# ----------------------
# Ground Truth: Deep Brain Stimulation Findings Elicited a clinical response in 60% of resistant depression patients after six months and clinical remission in 35% of patients, with benefits maintained for over 12 mo
# Best LLM Output: Physical exercise Associated with improvement in depression symptom and prevention of relapses
# Best Evaluation: 1. Retrieval: 0.5
# Explanation: The LLM output touches on the topic of depression improvement and prevention of relapses, which is related to the ground truth but does not directly address deep brain stimulation findings.
#
# 2. Augmentation: 0.7
# Explanation: The LLM output synthesizes the information about physical exercise and its impact on depression symptoms and relapses, which is coherent and relevant to the overall topic of mental health.
#
# 3. Generation: 0.9
# Explanation: The LLM output is fluent and grammatically correct, with no apparent issues in terms of language generation.
#
# 4. Attribution: 0.3
# Explanation: While the LLM output discusses a related topic of depression improvement, it does not directly attribute to the ground truth findings of deep brain stimulation in resistant depression patients. It makes a somewhat unsupported claim by not tying back to the original information.
# Retrieval Score: 0.5, Augmentation Score: 0.7, Generation Score: 0.9, Attribution Score: 0.3
# ----------------------
#                                         ground_truth  \
# 0  Pharmacotherapy Entails Monoamine oxidase inhi...
# 1                   Depression Side effect Mortality
# 2  Pharmacotherapy Entails Norepinephrine reuptak...
# 3           Depression Side effect Suicidal behavior
# 4  Monoamine oxidase inhibitors Same efficacy as ...
# 5  Trazodone Use In low doses as a sedative hypnotic
# 6                 SSRIs Is a part of Pharmacotherapy
# 7  Monoamine oxidase inhibitors Eligible for  Pat...
# 8                  Nefazodone Is comparable to  SSRI
# 9  Monoamine oxidase inhibitors Side effects Hepa...
#
#                                      best_llm_output  \
# 0  Monoamine Oxidase Inhibitors (MAOIs) less comm...
# 1  Anxious depression side effects high mean QIDS...
# 2  Selective Serotonin Reuptake Inhibitors (SSRIs...
# 3  Major Depressive Disorder Symptom high rates o...
# 4  Monoamine Oxidase Inhibitors (MAOIs) Less comm...
# 5  Major Depression Definition a mental health di...
# 6  Major Depressive Disorder Definition a prevale...
# 7  Escitalopram and Sertraline Properties Show th...
# 8              Sertraline Comparable to Escitalopram
# 9  Monoamine Oxidase Inhibitors Less commonly use...
#
#                                      best_evaluation  retrieval  augmentation  \
# 0  1. Retrieval: 0.8\nThe LLM output does a good ...       0.80           0.7
# 1  1. Retrieval: 0.75 \nThe LLM output does a goo...       0.75           0.8
# 2  1. Retrieval: 0.5\nThe LLM output does not dir...       0.50           0.7
# 3  1. Retrieval: 0.8\nThe LLM output does a good ...       0.80           0.7
# 4  1. Retrieval: 0.5\nThe LLM output partially re...       0.50           0.3
# 5  1. Retrieval: 0\nThe LLM output does not retri...       0.00           0.0
# 6  1. Retrieval: 0.5\nThe LLM output does not dir...       0.50           0.8
# 7  1. Retrieval: 0.5\nThe LLM output does not dir...       0.50           0.8
# 8  1. Retrieval: 0.5\nThe LLM output does not dir...       0.50           0.8
# 9  1. Retrieval: 0.5\nThe LLM output partially re...       0.50           0.2
#
#    generation  attribution
# 0         0.9         0.80
# 1         0.9         0.85
# 2         0.8         0.30
# 3         0.9         0.80
# 4         0.7         0.40
# 5         1.0         0.00
# 6         0.9         0.30
# 7         0.9         0.30
# 8         0.9         0.60
# 9         0.8         0.30
